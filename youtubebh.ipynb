# %%
from googleapiclient.discovery import build
import pymongo
import psycopg2
from psycopg2 import sql
import pandas as pd
import streamlit as st

# %%
# API key Connection

def api_connect():
    api_id="AIzaSyAorTAYXklQGb2YNZClduvQcZynl7O7e5Q"
    api_service_name="youtube"
    api_version="v3"

    youtube=build(api_service_name,api_version,developerKey=api_id)
    
    return youtube

youtube=api_connect()

# %%
# channel ID (TCDS)                       - 'UCVRi4KY1YQ6kNkKgR-pvk0A'
# channel ID (mr.gk)                      - 'UC5cY198GU1MQMIPJgMkCJ_Q'
# channel ID (tamil bussiness podcast)    - 'UCy1lBBbXhtfzugF_LK2b6Yw'
# channel ID (science with sam)           - 'UChGd9JY4yMegY6PxqpBjpRA'
# channel ID (Chandru Bharathy)           - 'UCS9ylflS6E0AvXg0LZ0P6_g'
# channel ID (King Kepler Network)        - 'UC3k6Cfk_BNGiGVX_s5UCs6Q'
# channel ID (Tamil trending Media)       - 'UCna0KHJFL0Ru81pwI2tCbGw'
# channel ID (Tamil Academy)              - 'UCbJ9KR5rKDrjzIamrbUmEKQ'
# channel ID (Endless Knowledga)          - 'UCApUMSkgDT8ayJZU8jBweYw'
# channel ID (Error Makes Clever Academy) - 'UCwr-evhuzGZgDFrq_1pLt_A'

# %%
request = youtube.channels().list(
    part="snippet,ContentDetails,statistics", 
    id="UCVRi4KY1YQ6kNkKgR-pvk0A"

)

response=request.execute()

# %%
response["items"][0]
# Out:
# {'kind': 'youtube#channel',
#  'etag': 'ceg-uHQAAH_906eRopJUIHPam8g',
#  'id': 'UCVRi4KY1YQ6kNkKgR-pvk0A',
#  'snippet': {'title': 'TCDS COMPUTER EDUCATION',
#   'description': 'இந்த சேனலின் முக்கிய நோக்கம் :\n\n1. அனைவருக்கும் தரமான கம்ப்யூட்டர் கல்வியை கற்றுத் தருவது.\n2. கருத்தியல் மற்றும் செய்முறைக்கென தனித்தனியாக எளிய தமிழ் மொழியில் பயிற்சிகளை வழங்குவது.\n3. உடனடி வேலை வாய்ப்பிற்கேற்ற பயிற்சிகளை வழங்குவது.\n4. புதிதாக கம்ப்யூட்டர் பயிற்சி மையங்களை துவங்கி வெற்றி கரமாக நடத்த வழி காட்டுவது.\n5. இந்த வீடியோக்கள் மூலம் கற்றுக் கொள்பவர்களுக்கு தமிழகத்தின் அனைத்து மாவட்டங்களிலும் உள்ள எங்களது TCDS கம்ப்யூட்டர் பயிற்சி மையத்தின் மூலம் நேரடியாக கம்ப்யூட்டரில் செய்முறை பயிற்சி செய்து பார்க்க வழி காட்டுவது.\n6. இச் சேனல் மூலம் பயிற்சி பெறுபவர்களுக்கு எங்களது பயிற்சி மையங்களின் மூலமாக தரமான பாட புத்தகங்களும் அரசு பதிவு பெற்ற மற்றும் ISO தரம் பெற்ற சான்றிதழ்களும் வழங்கப்படும்.\n7. தாங்கள் இந்த சேனலுக்கு நல்ல ஆதரவு கொடுப்பதன் மூலம், மேலும் பல சேவைகளை செய்ய காத்துக் கொண்டுள்ளோம்.\n பயன்படுத்துங்கள்!!!       வெற்றி பெறுங்கள்!!!     ஆதரவு தாருங்கள்!!!\nCELL: 98428 15883\n\nFRANCHISE APPROVAL FEES : Rs. 15000/-\n*  Govt. Regd.\n*  ISO Approved.\n*  Quality Books\n*  25 Years Experience. ',
#   'customUrl': '@tcdscomputereducation8775',
#   'publishedAt': '2020-03-28T03:13:07.59333Z',
#   'thumbnails': {'default': {'url': 'https://yt3.ggpht.com/UuVzVq4R__2AdRhY9TcFsN5xhFwJbOG1C1bI6ZSJa_iP108hPtbLLhK7F1x0dd9GENSd27nF=s88-c-k-c0x00ffffff-no-rj',
#     'width': 88,
#     'height': 88},
#    'medium': {'url': 'https://yt3.ggpht.com/UuVzVq4R__2AdRhY9TcFsN5xhFwJbOG1C1bI6ZSJa_iP108hPtbLLhK7F1x0dd9GENSd27nF=s240-c-k-c0x00ffffff-no-rj',
#     'width': 240,
#     'height': 240},
#    'high': {'url': 'https://yt3.ggpht.com/UuVzVq4R__2AdRhY9TcFsN5xhFwJbOG1C1bI6ZSJa_iP108hPtbLLhK7F1x0dd9GENSd27nF=s800-c-k-c0x00ffffff-no-rj',
#     'width': 800,
#     'height': 800}},
#   'localized': {'title': 'TCDS COMPUTER EDUCATION',
#    'description': 'இந்த சேனலின் முக்கிய நோக்கம் :\n\n1. அனைவருக்கும் தரமான கம்ப்யூட்டர் கல்வியை கற்றுத் தருவது.\n2. கருத்தியல் மற்றும் செய்முறைக்கென தனித்தனியாக எளிய தமிழ் மொழியில் பயிற்சிகளை வழங்குவது.\n3. உடனடி வேலை வாய்ப்பிற்கேற்ற பயிற்சிகளை வழங்குவது.\n4. புதிதாக கம்ப்யூட்டர் பயிற்சி மையங்களை துவங்கி வெற்றி கரமாக நடத்த வழி காட்டுவது.\n5. இந்த வீடியோக்கள் மூலம் கற்றுக் கொள்பவர்களுக்கு தமிழகத்தின் அனைத்து மாவட்டங்களிலும் உள்ள எங்களது TCDS கம்ப்யூட்டர் பயிற்சி மையத்தின் மூலம் நேரடியாக கம்ப்யூட்டரில் செய்முறை பயிற்சி செய்து பார்க்க வழி காட்டுவது.\n6. இச் சேனல் மூலம் பயிற்சி பெறுபவர்களுக்கு எங்களது பயிற்சி மையங்களின் மூலமாக தரமான பாட புத்தகங்களும் அரசு பதிவு பெற்ற மற்றும் ISO தரம் பெற்ற சான்றிதழ்களும் வழங்கப்படும்.\n7. தாங்கள் இந்த சேனலுக்கு நல்ல ஆதரவு கொடுப்பதன் மூலம், மேலும் பல சேவைகளை செய்ய காத்துக் கொண்டுள்ளோம்.\n பயன்படுத்துங்கள்!!!       வெற்றி பெறுங்கள்!!!     ஆதரவு தாருங்கள்!!!\nCELL: 98428 15883\n\nFRANCHISE APPROVAL FEES : Rs. 15000/-\n*  Govt. Regd.\n*  ISO Approved.\n*  Quality Books\n*  25 Years Experience. '},
#   'country': 'IN'},
#  'contentDetails': {'relatedPlaylists': {'likes': '',
#    'uploads': 'UUVRi4KY1YQ6kNkKgR-pvk0A'}},
#  'statistics': {'viewCount': '55893',
#   'subscriberCount': '1730',
#   'hiddenSubscriberCount': False,
#   'videoCount': '168'}}

# %%
# for i in response['items']:
#     data = dict(Channel_Name=i["snippet"]["title"],
#                 Channel_id = i["id"],
#                 Subsriber = i["statistics"]["subscriberCount"],
#                 views = i["statistics"]["viewCount"],
#                 Total_videos = i["statistics"]["videoCount"],
#                 Channel_Description = i["snippet"]["description"],
#                 Playlist_id = i["contentDetails"]["relatedPlaylists"]["uploads"])
#     print(data)

# %%
response['items'][0]['snippet']['title'] #example for output getting
# Out:
# 'TCDS COMPUTER EDUCATION'

# %%
# Get Channel Details

def get_channel_info(channel_id):
    request = youtube.channels().list(
        part="snippet,ContentDetails,statistics", 
        id=channel_id

    )

    response=request.execute()

    for i in response['items']:
        data = dict(Channel_Name=i["snippet"]["title"],
                    Channel_Id = i["id"],
                    Subscribers = i["statistics"]["subscriberCount"],
                    Views = i["statistics"]["viewCount"],
                    Total_Videos = i["statistics"]["videoCount"],
                    Channel_Description = i["snippet"]["description"],
                    Playlist_Id = i["contentDetails"]["relatedPlaylists"]["uploads"])
    return data

# %%
channel_details = get_channel_info("UCVRi4KY1YQ6kNkKgR-pvk0A")

# %%
channel_details
# Out:
# {'Channel_Name': 'TCDS COMPUTER EDUCATION',
#  'Channel_Id': 'UCVRi4KY1YQ6kNkKgR-pvk0A',
#  'Subscribers': '1730',
#  'Views': '55893',
#  'Total_Videos': '168',
#  'Channel_Description': 'இந்த சேனலின் முக்கிய நோக்கம் :\n\n1. அனைவருக்கும் தரமான கம்ப்யூட்டர் கல்வியை கற்றுத் தருவது.\n2. கருத்தியல் மற்றும் செய்முறைக்கென தனித்தனியாக எளிய தமிழ் மொழியில் பயிற்சிகளை வழங்குவது.\n3. உடனடி வேலை வாய்ப்பிற்கேற்ற பயிற்சிகளை வழங்குவது.\n4. புதிதாக கம்ப்யூட்டர் பயிற்சி மையங்களை துவங்கி வெற்றி கரமாக நடத்த வழி காட்டுவது.\n5. இந்த வீடியோக்கள் மூலம் கற்றுக் கொள்பவர்களுக்கு தமிழகத்தின் அனைத்து மாவட்டங்களிலும் உள்ள எங்களது TCDS கம்ப்யூட்டர் பயிற்சி மையத்தின் மூலம் நேரடியாக கம்ப்யூட்டரில் செய்முறை பயிற்சி செய்து பார்க்க வழி காட்டுவது.\n6. இச் சேனல் மூலம் பயிற்சி பெறுபவர்களுக்கு எங்களது பயிற்சி மையங்களின் மூலமாக தரமான பாட புத்தகங்களும் அரசு பதிவு பெற்ற மற்றும் ISO தரம் பெற்ற சான்றிதழ்களும் வழங்கப்படும்.\n7. தாங்கள் இந்த சேனலுக்கு நல்ல ஆதரவு கொடுப்பதன் மூலம், மேலும் பல சேவைகளை செய்ய காத்துக் கொண்டுள்ளோம்.\n பயன்படுத்துங்கள்!!!       வெற்றி பெறுங்கள்!!!     ஆதரவு தாருங்கள்!!!\nCELL: 98428 15883\n\nFRANCHISE APPROVAL FEES : Rs. 15000/-\n*  Govt. Regd.\n*  ISO Approved.\n*  Quality Books\n*  25 Years Experience. ',
#  'Playlist_Id': 'UUVRi4KY1YQ6kNkKgR-pvk0A'}

# %%
# get video id's

def get_video_ids(channel_id):

    video_ids = []
    response = youtube.channels().list(id=channel_id,
                                        part="contentDetails").execute()
    Playlist_id = response['items'][0]['contentDetails']['relatedPlaylists']['uploads']

    next_page_token = None

    while True:

        response1 = youtube.playlistItems().list(
            part = 'snippet',
            playlistId = Playlist_id,
            maxResults=50,
            pageToken=next_page_token).execute()

        for i in range (len(response1 ['items'])):
            video_ids.append(response1 ['items'][i]['snippet']['resourceId']['videoId'])

        next_page_token = response1.get ('nextPageToken')

        if next_page_token is None:
            break

    return video_ids

# %%
Video_Ids = get_video_ids('UCVRi4KY1YQ6kNkKgR-pvk0A')

# %%
len(Video_Ids)
# Out:
# 168

# %%
Video_Ids
# Out:
# ['VjMC6-yczII',
#  'd2Ls52t5KpA',
#  'vaqFZioLEXk',
#  'BvBN25EzYg0',
#  'tP3qyiVE4pg',
#  '0EuTJk-3XOM',
#  'szKspOQ5h8s',
#  'HlOfh2qHC6k',
#  '2RNg3FN1U4g',
#  'erQqf7TeT6g',
#  'Dj6i5x_r9ow',
#  'LYPlSgSTLq4',
#  'PahjtYJ0nR8',
#  '52uOR0kFRac',
#  '7Tq2-9YqYak',
#  'aHtwv4q1ivU',
#  'BEUQwz8dwTE',
#  'dsuAHNQ2pjY',
#  'Dbm2GHXHN98',
#  'oX3caV-LPuo',
#  'pjUipf59GtE',
#  'FCIrXtA5bPw',
#  '9yAK2WWpK2U',
#  'qjyw8E-kODI',
#  'FkgJgUoHMO8',
#  '-lkZJW-u6SE',
#  'bZ2C7kBr2uo',
#  '40iaejXZe44',
#  'dzGh8gLcmg4',
#  'ZkWJRBno-KE',
#  't2linI2w2b8',
#  'dZbIChinTw4',
#  'Ox9tCa8LtBs',
#  'nVVr-bNWe6c',
#  'O-XGCubjiwA',
#  'iDTzHA_tw2s',
#  'MHhhqiX2HMY',
#  'YNQ3Cww5GUI',
#  '_JUpLNFjImk',
#  'IueriRiXlTM',
#  'W6_yktK28i0',
#  'akzoKKboSq8',
#  'p1hWs9lEZuM',
#  '1RU5LkGmIeg',
#  'yVtau9xsukg',
#  'li_A8S8iYCY',
#  'XFTwmPUEVes',
#  'dk_tDeUdxQ8',
#  'XAnxrDGzNeM',
#  'NVtRlFc4sRY',
#  '6g-xNOXKcto',
#  'iYtpG63B7fc',
#  'TKl7VofGh00',
#  'NScPoc-mFAI',
#  'WolliVBYaCc',
#  'Vruen6d2d7c',
#  'k7WyclG9KeU',
#  'LqtxueUmEBw',
#  'dEYc2rEqGT8',
#  '4CVw8CUzT_g',
#  'SkGqHDgk3GY',
#  'BRzrgLUnXgw',
#  'yHZZ498-Ciw',
#  'QkwWXNSPvt8',
#  'hk6j-8flGJ4',
#  'SrE9ESK2aXs',
#  'eYmrpxp5dZE',
#  'HrrSB8OWKbA',
#  'IhVfwCwcBxQ',
#  'cFQrjXv_Mlk',
#  'QOLR0Iftc0M',
#  'KXDDGpCrREk',
#  'Fxq--YEoiJI',
#  'y-2c79GYcmE',
#  'ucHS1MwJ6lI',
#  'h9ria7USxv0',
#  's5Wb-JAp6zY',
#  'vblULKaYCtg',
#  'fRAZchQnNnI',
#  'ETnarRAQ2sM',
#  'gK3HU1gjb8E',
#  'yTZJFIZXdR4',
#  'diQHbA2O1kg',
#  'Ec6jjduAgSg',
#  'YGzk5xSdyNI',
#  '5VdHb9nIU_8',
#  'hiLrxd2llP8',
#  'ik49Q87-UVg',
#  'OZLgijz8yFU',
#  'BQoAShHkCxg',
#  'Cz9zEVBPLbc',
#  'Uigbl3eGvkg',
#  'z8yrhUZqae8',
#  'QyWDePmODE8',
#  'C9QnF2JWVIs',
#  '_4JAb86GhjM',
#  '6Q3tfzQuPFI',
#  'Jue4d-7QdAA',
#  'H0T3vBUUIvA',
#  '3nxQPRNtj50',
#  'TdMfIBD00hA',
#  'NmqvmWK5LDA',
#  'D7V3FMiqAmU',
#  'JAvO-7Pj2X8',
#  'jiK9xufRBoA',
#  'Otni0ebOIxY',
#  'HX44Dh1LCRs',
#  'QWjLg87QomM',
#  '7lZucgceVwY',
#  'X8YAzUqSwQQ',
#  'Yv3i4-DpqKc',
#  'CeCt8Ay6XWc',
#  '5LF0SlTWKfU',
#  '9R4__Aoncmc',
#  'RRzbBvEloXE',
#  'bFMGj3pKDAc',
#  '0gGWHMkHUxo',
#  'JPKPtLHDQrQ',
#  'qyO35ZTAeIc',
#  'TPPAsipuwdI',
#  'LJCnwWln_0Q',
#  'HtjqH8c-O_Y',
#  'M1G5t0drYQU',
#  'vq6u1m-v9dY',
#  '1i-mYQRFBBo',
#  'cnZI_Km6-mM',
#  'do0KA30oEzY',
#  'X3OmRQGXK4k',
#  'bzYijB2kkYw',
#  'BqnDI6nKKo0',
#  'LWvMOC8rw_M',
#  'JIY90OsB8bA',
#  'YflWA5oZeug',
#  'ymg9Fhhwbgk',
#  'CDAmEBjO_z0',
#  'e8Kmpz1xGnY',
#  'pbI50DykmTE',
#  'kp7guPJ7FMU',
#  '0xp9nMLf61Y',
#  'Se9eTmuAdME',
#  'oa7dI3vmuIc',
#  'LbzbDLnEDF8',
#  '4AFtWrHp9L0',
#  '-zs8P_eVOcE',
#  'mAtmzpt-No0',
#  'TxLCYU-l_Xo',
#  'aO-5UkJn_gY',
#  'Ji8gDz0CzQU',
#  '-91LYZ-A9b8',
#  '1sTVFztk4c0',
#  'WySwdj1DyQw',
#  'mYCHxPsIMO0',
#  'DQ7__f78sUc',
#  'XvxKJELxDSY',
#  'W3QdUBkSh1Q',
#  'M7DjoEJ78Ic',
#  '4QoiAWBXLtw',
#  'sWWkzert6Kg',
#  'ihVMY7FHebM',
#  'Z00Sot0aRjI',
#  '42JvaVtNGpE',
#  'c4sp-8VXrEY',
#  '-4sZAnuLSXI',
#  'Z1G8XepBDT4',
#  'kSBqcGuMxeg',
#  'XXCimlXY1MM',
#  '0gVsNO1Gusg',
#  'YpIf_2wOu7A']

# %%
# get video information

def get_video_info(video_ids):

    video_data = []

    for video_id in video_ids:
        request = youtube.videos().list(
            part = "snippet,ContentDetails,statistics",
            id = video_id
        )

        response = request.execute()

        for item in response ['items']:
            data = dict(Channel_Name = item['snippet']['channelTitle'],
                        Channel_Id = item['snippet']['channelId'],
                        Video_Id = item['id'],
                        Title = item['snippet']['title'],
                        Tags = item['snippet'].get('tags'),
                        Thumbnail = item['snippet']['thumbnails']['default']['url'],
                        Description = item['snippet'].get('description'),
                        Published_Date = item.get('publishAt'),
                        Duration = item['contentDetails']['duration'],
                        Views = item['statistics'].get('viewCount'),
                        Likes = item['statistics'].get('likeCount'),
                        Comments = item['statistics'].get('commentCount'),
                        Favorite_count = item['statistics']['favoriteCount'],
                        Definition = item['contentDetails']['definition'],
                        Caption_status = item['contentDetails']['caption']
                        )
            video_data.append(data)
    return video_data

# %%
video_details = get_video_info(Video_Ids)

# %%
video_details
# Out:
# [{'Channel_Name': 'TCDS COMPUTER EDUCATION',
#   'Channel_Id': 'UCVRi4KY1YQ6kNkKgR-pvk0A',
#   'Video_Id': 'VjMC6-yczII',
#   'Title': 'MS POWERPOINT / BASIC COMPUTER CLASS IN TAMIL [CLASS-6]',
#   'Tags': ['how to start computer training centre',
#    'how to open computer centre',
#    'PowerPoint Tutorial',
#    'Presentation Tips',
#    'Slide Design',
#    'Microsoft PowerPoint',
#    'PowerPoint Tricks',
#    'PowerPoint Tips & Tricks',
#    'PowerPoint Hacks',
#    'PowerPoint Animation',
#    'PowerPoint Techniques',
#    'PowerPoint Templates',
#    'PowerPoint Masterclass',
#    'PowerPoint for Beginners',
#    'Advanced PowerPoint',
#    'basic computer class in tamil',
#    'PowerPoint Slide Examples',
#    'Presentation Design Ideas',
#    'Creative PowerPoint',
#    'Slide Deck Tips'],
#   'Thumbnail': 'https://i.ytimg.com/vi/VjMC6-yczII/default.jpg',
#   'Description': 'In this video we teach you, about Computer Basics in Tamil with step by step method to learn easily.\n\nTo Support and motivate me please Subscribe, Share and Like this channel\n\nI Will also teach you high scope and valuable computer courses through this channel that are mentioned below :\n\nFREE JOB & BUSINESS ORIENTED COMPUTER COURSE with Government approved Course completed Certificate',
#   'Published_Date': None,
#   'Duration': 'PT26M51S',
#   'Views': '15',
#   'Likes': '0',
#   'Comments': '0',
#   'Favorite_count': '0',
#   'Definition': 'hd',
#   'Caption_status': 'false'},
#  {'Channel_Name': 'TCDS COMPUTER EDUCATION',
#   'Channel_Id': 'UCVRi4KY1YQ6kNkKgR-pvk0A',
#   'Video_Id': 'd2Ls52t5KpA',
#   'Title': 'PYTHON / BASIC COMPUTER  LAB IN TAMIL [LAB-9]',
#   'Tags': ['how to open computer centre',
#    'diploma courses after 12th',
#    'top 10 computer education centres',
#    'best computer training centres',
#    'tcds computer',
#    'csri computer',
#    'tcds',
#    'csri',
#    'computer centres in tamilnadu',
#    'tcds computer education',
#    'csri computer education',
#    'computer in tamil',
#    'certificate course',
#    'PYTHON',
#    'How to use python',
#    'very easy learn in python',
#    'step by step learning python in tamil',
#    'python practice',
#    'python classes',
#    'basic python in tamil',
#    'how to learn pyhton',
#    'python tutorial'],
#   'Thumbnail': 'https://i.ytimg.com/vi/d2Ls52t5KpA/default.jpg',
#   'Description': 'In this video we teach you, about Computer Basics in Tamil with step by step method to learn easily.\n\nTo Support and motivate me please Subscribe, Share and Like this channel\n\nI Will also teach you high scope and valuable computer courses through this channel that are mentioned below :\n\nFREE JOB & BUSINESS ORIENTED COMPUTER COURSE with Government approved Course completed Certificate',
#   'Published_Date': None,
#   'Duration': 'PT10M8S',
#   'Views': '66',
#   'Likes': '0',
#   'Comments': '1',
#   'Favorite_count': '0',
#   'Definition': 'hd',
#   'Caption_status': 'false'},
#  {'Channel_Name': 'TCDS COMPUTER EDUCATION',
#   'Channel_Id': 'UCVRi4KY1YQ6kNkKgR-pvk0A',
#   'Video_Id': 'vaqFZioLEXk',
#   'Title': 'MS POWERPOINT / BASIC COMPUTER LAB IN TAMIL [LAB-5]',
#   'Tags': ['how to start computer training centre',
#    'how to open computer centre',
#    'PowerPoint Tutorial',
#    'Presentation Tips',
#    'Slide Design',
#    'Microsoft PowerPoint',
#    'PowerPoint Tricks',
#    'PowerPoint Tips & Tricks',
#    'PowerPoint Hacks',
#    'PowerPoint Animation',
#    'PowerPoint Techniques',
#    'PowerPoint Templates',
#    'PowerPoint Masterclass',
#    'PowerPoint for Beginners',
#    'Advanced PowerPoint',
#    'basic computer class in tamil',
#    'PowerPoint Slide Examples',
#    'Presentation Design Ideas',
#    'Creative PowerPoint',
#    'Slide Deck Tips'],
#   'Thumbnail': 'https://i.ytimg.com/vi/vaqFZioLEXk/default.jpg',
#   'Description': 'In this video we teach you, about Computer Basics in Tamil with step by step method to learn easily.\n\nTo Support and motivate me please Subscribe, Share and Like this channel\n\nI Will also teach you high scope and valuable computer courses through this channel that are mentioned below :\n\nFREE JOB & BUSINESS ORIENTED COMPUTER COURSE with Government approved Course completed Certificate',
#   'Published_Date': None,
#   'Duration': 'PT9M20S',
#   'Views': '33',
#   'Likes': '0',
#   'Comments': '0',
#   'Favorite_count': '0',
#   'Definition': 'hd',
#   'Caption_status': 'false'},
#  {'Channel_Name': 'TCDS COMPUTER EDUCATION',
#   'Channel_Id': 'UCVRi4KY1YQ6kNkKgR-pvk0A',
#   'Video_Id': 'BvBN25EzYg0',
#   'Title': 'PYTHON / BASIC COMPUTER  CLASS IN TAMIL [CLASS-15]',
#   'Tags': ['how to open computer centre',
#    'diploma courses after 12th',
#    'top 10 computer education centres',
#    'best computer training centres',
#    'tcds computer',
#    'csri computer',
#    'tcds',
#    'csri',
#    'computer centres in tamilnadu',
#    'tcds computer education',
#    'csri computer education',
#    'computer in tamil',
#    'certificate course',
#    'PYTHON',
#    'How to use python',
#    'very easy learn in python',
#    'step by step learning python in tamil',
#    'python practice',
#    'python classes',
#    'basic python in tamil',
#    'how to learn pyhton',
#    'python tutorial'],
#   'Thumbnail': 'https://i.ytimg.com/vi/BvBN25EzYg0/default.jpg',
#   'Description': 'In this video we teach you, about Computer Basics in Tamil with step by step method to learn easily.\n\nTo Support and motivate me please Subscribe, Share and Like this channel\n\nI Will also teach you high scope and valuable computer courses through this channel that are mentioned below :\n\nFREE JOB & BUSINESS ORIENTED COMPUTER COURSE with Government approved Course completed Certificate',
#   'Published_Date': None,
#   'Duration': 'PT17M45S',
#   'Views': '73',
#   'Likes': '6',
#   'Comments': '0',
#   'Favorite_count': '0',
#   'Definition': 'hd',
#   'Caption_status': 'false'},
#  {'Channel_Name': 'TCDS COMPUTER EDUCATION',
#   'Channel_Id': 'UCVRi4KY1YQ6kNkKgR-pvk0A',
#   'Video_Id': 'tP3qyiVE4pg',
#   'Title': 'MS POWERPOINT / BASIC COMPUTER CLASS IN TAMIL [CLASS-5]',
#   'Tags': ['how to start computer training centre',
#    'how to open computer centre',
#    'PowerPoint Tutorial',
#    'Presentation Tips',
#    'Slide Design',
#    'Microsoft PowerPoint',
#    'PowerPoint Tricks',
#    'PowerPoint Tips & Tricks',
#    'PowerPoint Hacks',
#    'PowerPoint Animation',
#    'PowerPoint Techniques',
#    'PowerPoint Templates',
#    'PowerPoint Masterclass',
#    'PowerPoint for Beginners',
#    'Advanced PowerPoint',
#    'basic computer class in tamil',
#    'PowerPoint Slide Examples',
#    'Presentation Design Ideas',
#    'Creative PowerPoint',
#    'Slide Deck Tips'],
#   'Thumbnail': 'https://i.ytimg.com/vi/tP3qyiVE4pg/default.jpg',
#   'Description': 'In this video we teach you, about Computer Basics in Tamil with step by step method to learn easily.\n\nTo Support and motivate me please Subscribe, Share and Like this channel\n\nI Will also teach you high scope and valuable computer courses through this channel that are mentioned below :\n\nFREE JOB & BUSINESS ORIENTED COMPUTER COURSE with Government approved Course completed Certificate',
#   'Published_Date': None,
#   'Duration': 'PT26M35S',
#   'Views': '98',
#   'Likes': '3',
#   'Comments': '0',
#   'Favorite_count': '0',
#   'Definition': 'hd',
#   'Caption_status': 'false'},
#  {'Channel_Name': 'TCDS COMPUTER EDUCATION',
#   'Channel_Id': 'UCVRi4KY1YQ6kNkKgR-pvk0A',
#   'Video_Id': '0EuTJk-3XOM',
#   'Title': 'PYTHON / BASIC COMPUTER  LAB IN TAMIL [LAB-8]',
#   'Tags': ['how to open computer centre',
#    'diploma courses after 12th',
#    'top 10 computer education centres',
#    'best computer training centres',
#    'tcds computer',
#    'csri computer',
#    'tcds',
#    'csri',
#    'computer centres in tamilnadu',
#    'tcds computer education',
#    'csri computer education',
#    'computer in tamil',
#    'certificate course',
#    'PYTHON',
#    'How to use python',
#    'very easy learn in python',
#    'step by step learning python in tamil',
#    'python practice',
#    'python classes',
#    'basic python in tamil',
#    'how to learn pyhton',
#    'python tutorial'],
#   'Thumbnail': 'https://i.ytimg.com/vi/0EuTJk-3XOM/default.jpg',
#   'Description': 'In this video we teach you, about Computer Basics in Tamil with step by step method to learn easily.\n\nTo Support and motivate me please Subscribe, Share and Like this channel\n\nI Will also teach you high scope and valuable computer courses through this channel that are mentioned below :\n\nFREE JOB & BUSINESS ORIENTED COMPUTER COURSE with Government approved Course completed Certificate',
#   'Published_Date': None,
#   'Duration': 'PT14M33S',
#   'Views': '59',
#   'Likes': '1',
#   'Comments': '0',
#   'Favorite_count': '0',
#   'Definition': 'hd',
#   'Caption_status': 'false'},
#  {'Channel_Name': 'TCDS COMPUTER EDUCATION',
#   'Channel_Id': 'UCVRi4KY1YQ6kNkKgR-pvk0A',
#   'Video_Id': 'szKspOQ5h8s',
#   'Title': 'MS POWERPOINT / BASIC COMPUTER CLAB IN TAMIL [LAB-4]',
#   'Tags': ['how to start computer training centre',
#    'how to open computer centre',
#    'PowerPoint Tutorial',
#    'Presentation Tips',
#    'Slide Design',
#    'Microsoft PowerPoint',
#    'PowerPoint Tricks',
#    'PowerPoint Tips & Tricks',
#    'PowerPoint Hacks',
#    'PowerPoint Animation',
#    'PowerPoint Techniques',
#    'PowerPoint Templates',
#    'PowerPoint Masterclass',
#    'PowerPoint for Beginners',
#    'Advanced PowerPoint',
#    'basic computer class in tamil',
#    'PowerPoint Slide Examples',
#    'Presentation Design Ideas',
#    'Creative PowerPoint',
#    'Slide Deck Tips'],
#   'Thumbnail': 'https://i.ytimg.com/vi/szKspOQ5h8s/default.jpg',
#   'Description': 'In this video we teach you, about Computer Basics in Tamil with step by step method to learn easily.\n\nTo Support and motivate me please Subscribe, Share and Like this channel\n\nI Will also teach you high scope and valuable computer courses through this channel that are mentioned below :\n\nFREE JOB & BUSINESS ORIENTED COMPUTER COURSE with Government approved Course completed Certificate',
#   'Published_Date': None,
#   'Duration': 'PT11M6S',
#   'Views': '68',
#   'Likes': '1',
#   'Comments': '0',
#   'Favorite_count': '0',
#   'Definition': 'hd',
#   'Caption_status': 'false'},
#  {'Channel_Name': 'TCDS COMPUTER EDUCATION',
#   'Channel_Id': 'UCVRi4KY1YQ6kNkKgR-pvk0A',
#   'Video_Id': 'HlOfh2qHC6k',
#   'Title': 'PYTHON / BASIC COMPUTER  CLASS IN TAMIL [CLASS-14]',
#   'Tags': ['how to open computer centre',
#    'diploma courses after 12th',
#    'top 10 computer education centres',
#    'best computer training centres',
#    'tcds computer',
#    'csri computer',
#    'tcds',
#    'csri',
#    'computer centres in tamilnadu',
#    'tcds computer education',
#    'csri computer education',
#    'computer in tamil',
#    'certificate course',
#    'PYTHON',
#    'How to use python',
#    'very easy learn in python',
#    'step by step learning python in tamil',
#    'python practice',
#    'python classes',
#    'basic python in tamil',
#    'how to learn pyhton',
#    'python tutorial'],
#   'Thumbnail': 'https://i.ytimg.com/vi/HlOfh2qHC6k/default.jpg',
#   'Description': 'In this video we teach you, about Computer Basics in Tamil with step by step method to learn easily.\n\nTo Support and motivate me please Subscribe, Share and Like this channel\n\nI Will also teach you high scope and valuable computer courses through this channel that are mentioned below :\n\nFREE JOB & BUSINESS ORIENTED COMPUTER COURSE with Government approved Course completed Certificate',
#   'Published_Date': None,
#   'Duration': 'PT23M59S',
#   'Views': '88',
#   'Likes': '2',
#   'Comments': '1',
#   'Favorite_count': '0',
#   'Definition': 'hd',
#   'Caption_status': 'false'},
#  {'Channel_Name': 'TCDS COMPUTER EDUCATION',
#   'Channel_Id': 'UCVRi4KY1YQ6kNkKgR-pvk0A',
#   'Video_Id': '2RNg3FN1U4g',
#   'Title': 'MS POWERPOINT / BASIC COMPUTER CLASS IN TAMIL [CLASS-4]',
#   'Tags': ['how to start computer training centre',
#    'how to open computer centre',
#    'PowerPoint Tutorial',
#    'Presentation Tips',
#    'Slide Design',
#    'Microsoft PowerPoint',
#    'PowerPoint Tricks',
#    'PowerPoint Tips & Tricks',
#    'PowerPoint Hacks',
#    'PowerPoint Animation',
#    'PowerPoint Techniques',
#    'PowerPoint Templates',
#    'PowerPoint Masterclass',
#    'PowerPoint for Beginners',
#    'Advanced PowerPoint',
#    'basic computer class in tamil',
#    'PowerPoint Slide Examples',
#    'Presentation Design Ideas',
#    'Creative PowerPoint',
#    'Slide Deck Tips'],
#   'Thumbnail': 'https://i.ytimg.com/vi/2RNg3FN1U4g/default.jpg',
#   'Description': 'In this video we teach you, about Computer Basics in Tamil with step by step method to learn easily.\n\nTo Support and motivate me please Subscribe, Share and Like this channel\n\nI Will also teach you high scope and valuable computer courses through this channel that are mentioned below :\n\nFREE JOB & BUSINESS ORIENTED COMPUTER COURSE with Government approved Course completed Certificate',
#   'Published_Date': None,
#   'Duration': 'PT34M40S',
#   'Views': '56',
#   'Likes': '2',
#   'Comments': '0',
#   'Favorite_count': '0',
#   'Definition': 'hd',
#   'Caption_status': 'false'},
#  {'Channel_Name': 'TCDS COMPUTER EDUCATION',
#   'Channel_Id': 'UCVRi4KY1YQ6kNkKgR-pvk0A',
#   'Video_Id': 'erQqf7TeT6g',
#   'Title': 'PYTHON / BASIC COMPUTER  LAB IN TAMIL [LAB-7]',
#   'Tags': ['how to open computer centre',
#    'diploma courses after 12th',
#    'top 10 computer education centres',
#    'best computer training centres',
#    'tcds computer',
#    'csri computer',
#    'tcds',
#    'csri',
#    'computer centres in tamilnadu',
#    'tcds computer education',
#    'csri computer education',
#    'computer in tamil',
#    'certificate course',
#    'PYTHON',
#    'How to use python',
#    'very easy learn in python',
#    'step by step learning python in tamil',
#    'python practice',
#    'python classes',
#    'basic python in tamil',
#    'how to learn pyhton',
#    'python tutorial'],
#   'Thumbnail': 'https://i.ytimg.com/vi/erQqf7TeT6g/default.jpg',
#   'Description': 'In this video we teach you, about Computer Basics in Tamil with step by step method to learn easily.\n\nTo Support and motivate me please Subscribe, Share and Like this channel\n\nI Will also teach you high scope and valuable computer courses through this channel that are mentioned below :\n\nFREE JOB & BUSINESS ORIENTED COMPUTER COURSE with Government approved Course completed Certificate',
#   'Published_Date': None,
#   'Duration': 'PT17M27S',
#   'Views': '21',
#   'Likes': '0',
#   'Comments': '0',
#   'Favorite_count': '0',
#   'Definition': 'hd',
#   'Caption_status': 'false'},
#  {'Channel_Name': 'TCDS COMPUTER EDUCATION',
#   'Channel_Id': 'UCVRi4KY1YQ6kNkKgR-pvk0A',
#   'Video_Id': 'Dj6i5x_r9ow',
#   'Title': 'MS POWERPOINT / BASIC COMPUTER LAB IN TAMIL [LAB-3]',
#   'Tags': ['how to start computer training centre',
#    'how to open computer centre',
#    'PowerPoint Tutorial',
#    'Presentation Tips',
#    'Slide Design',
#    'Microsoft PowerPoint',
#    'PowerPoint Tricks',
#    'PowerPoint Tips & Tricks',
#    'PowerPoint Hacks',
#    'PowerPoint Animation',
#    'PowerPoint Techniques',
#    'PowerPoint Templates',
#    'PowerPoint Masterclass',
#    'PowerPoint for Beginners',
#    'Advanced PowerPoint',
#    'basic computer class in tamil',
#    'PowerPoint Slide Examples',
#    'Presentation Design Ideas',
#    'Creative PowerPoint',
#    'Slide Deck Tips'],
#   'Thumbnail': 'https://i.ytimg.com/vi/Dj6i5x_r9ow/default.jpg',
#   'Description': 'In this video we teach you, about Computer Basics in Tamil with step by step method to learn easily.\n\nTo Support and motivate me please Subscribe, Share and Like this channel\n\nI Will also teach you high scope and valuable computer courses through this channel that are mentioned below :\n\nFREE JOB & BUSINESS ORIENTED COMPUTER COURSE with Government approved Course completed Certificate',
#   'Published_Date': None,
#   'Duration': 'PT15M23S',
#   'Views': '43',
#   'Likes': '0',
#   'Comments': '0',
#   'Favorite_count': '0',
#   'Definition': 'hd',
#   'Caption_status': 'false'},
#  {'Channel_Name': 'TCDS COMPUTER EDUCATION',
#   'Channel_Id': 'UCVRi4KY1YQ6kNkKgR-pvk0A',
#   'Video_Id': 'LYPlSgSTLq4',
#   'Title': 'PYTHON / BASIC COMPUTER  CLASS IN TAMIL [CLASS-13]',
#   'Tags': ['how to open computer centre',
#    'diploma courses after 12th',
#    'top 10 computer education centres',
#    'best computer training centres',
#    'tcds computer',
#    'csri computer',
#    'tcds',
#    'csri',
#    'computer centres in tamilnadu',
#    'tcds computer education',
#    'csri computer education',
#    'computer in tamil',
#    'certificate course',
#    'PYTHON',
#    'How to use python',
#    'very easy learn in python',
#    'step by step learning python in tamil',
#    'python practice',
#    'python classes',
#    'basic python in tamil',
#    'how to learn pyhton',
#    'python tutorial'],
#   'Thumbnail': 'https://i.ytimg.com/vi/LYPlSgSTLq4/default.jpg',
#   'Description': 'In this video we teach you, about Computer Basics in Tamil with step by step method to learn easily.\n\nTo Support and motivate me please Subscribe, Share and Like this channel\n\nI Will also teach you high scope and valuable computer courses through this channel that are mentioned below :\n\nFREE JOB & BUSINESS ORIENTED COMPUTER COURSE with Government approved Course completed Certificate',
#   'Published_Date': None,
#   'Duration': 'PT14M12S',
#   'Views': '72',
#   'Likes': '1',
#   'Comments': '1',
#   'Favorite_count': '0',
#   'Definition': 'hd',
#   'Caption_status': 'false'},
#  {'Channel_Name': 'TCDS COMPUTER EDUCATION',
#   'Channel_Id': 'UCVRi4KY1YQ6kNkKgR-pvk0A',
#   'Video_Id': 'PahjtYJ0nR8',
#   'Title': 'MS POWERPOINT / BASIC COMPUTER CLASS IN TAMIL [CLASS-3]',
#   'Tags': ['how to start computer training centre',
#    'how to open computer centre',
#    'PowerPoint Tutorial',
#    'Presentation Tips',
#    'Slide Design',
#    'Microsoft PowerPoint',
#    'PowerPoint Tricks',
#    'PowerPoint Tips & Tricks',
#    'PowerPoint Hacks',
#    'PowerPoint Animation',
#    'PowerPoint Techniques',
#    'PowerPoint Templates',
#    'PowerPoint Masterclass',
#    'PowerPoint for Beginners',
#    'Advanced PowerPoint',
#    'basic computer class in tamil',
#    'PowerPoint Slide Examples',
#    'Presentation Design Ideas',
#    'Creative PowerPoint',
#    'Slide Deck Tips'],
#   'Thumbnail': 'https://i.ytimg.com/vi/PahjtYJ0nR8/default.jpg',
#   'Description': 'In this video we teach you, about Computer Basics in Tamil with step by step method to learn easily.\n\nTo Support and motivate me please Subscribe, Share and Like this channel\n\nI Will also teach you high scope and valuable computer courses through this channel that are mentioned below :\n\nFREE JOB & BUSINESS ORIENTED COMPUTER COURSE with Government approved Course completed Certificate',
#   'Published_Date': None,
#   'Duration': 'PT32M4S',
#   'Views': '109',
#   'Likes': '4',
#   'Comments': '0',
#   'Favorite_count': '0',
#   'Definition': 'hd',
#   'Caption_status': 'false'},
#  {'Channel_Name': 'TCDS COMPUTER EDUCATION',
#   'Channel_Id': 'UCVRi4KY1YQ6kNkKgR-pvk0A',
#   'Video_Id': '52uOR0kFRac',
#   'Title': 'PYTHON / BASIC COMPUTER  CLASS IN TAMIL [CLASS-12]',
#   'Tags': ['how to open computer centre',
#    'diploma courses after 12th',
#    'top 10 computer education centres',
#    'best computer training centres',
#    'tcds computer',
#    'csri computer',
#    'tcds',
#    'csri',
#    'computer centres in tamilnadu',
#    'tcds computer education',
#    'csri computer education',
#    'computer in tamil',
#    'certificate course',
#    'PYTHON',
#    'How to use python',
#    'very easy learn in python',
#    'step by step learning python in tamil',
#    'python practice',
#    'python classes',
#    'basic python in tamil',
#    'how to learn pyhton',
#    'python tutorial'],
#   'Thumbnail': 'https://i.ytimg.com/vi/52uOR0kFRac/default.jpg',
#   'Description': 'In this video we teach you, about Computer Basics in Tamil with step by step method to learn easily.\n\nTo Support and motivate me please Subscribe, Share and Like this channel\n\nI Will also teach you high scope and valuable computer courses through this channel that are mentioned below :\n\nFREE JOB & BUSINESS ORIENTED COMPUTER COURSE with Government approved Course completed Certificate',
#   'Published_Date': None,
#   'Duration': 'PT19M27S',
#   'Views': '92',
#   'Likes': '1',
#   'Comments': '1',
#   'Favorite_count': '0',
#   'Definition': 'hd',
#   'Caption_status': 'false'},
#  {'Channel_Name': 'TCDS COMPUTER EDUCATION',
#   'Channel_Id': 'UCVRi4KY1YQ6kNkKgR-pvk0A',
#   'Video_Id': '7Tq2-9YqYak',
#   'Title': 'MS POWERPOINT / BASIC COMPUTER LAB IN TAMIL [LAB-2]',
#   'Tags': ['how to start computer training centre',
#    'how to open computer centre',
#    'PowerPoint Tutorial',
#    'Presentation Tips',
#    'Slide Design',
#    'Microsoft PowerPoint',
#    'PowerPoint Tricks',
#    'PowerPoint Tips & Tricks',
#    'PowerPoint Hacks',
#    'PowerPoint Animation',
#    'PowerPoint Techniques',
#    'PowerPoint Templates',
#    'PowerPoint Masterclass',
#    'PowerPoint for Beginners',
#    'Advanced PowerPoint',
#    'basic computer class in tamil',
#    'PowerPoint Slide Examples',
#    'Presentation Design Ideas',
#    'Creative PowerPoint',
#    'Slide Deck Tips'],
#   'Thumbnail': 'https://i.ytimg.com/vi/7Tq2-9YqYak/default.jpg',
#   'Description': 'In this video we teach you, about Computer Basics in Tamil with step by step method to learn easily.\n\nTo Support and motivate me please Subscribe, Share and Like this channel\n\nI Will also teach you high scope and valuable computer courses through this channel that are mentioned below :\n\nFREE JOB & BUSINESS ORIENTED COMPUTER COURSE with Government approved Course completed Certificate',
#   'Published_Date': None,
#   'Duration': 'PT14M14S',
#   'Views': '27',
#   'Likes': '0',
#   'Comments': '0',
#   'Favorite_count': '0',
#   'Definition': 'hd',
#   'Caption_status': 'false'},
#  {'Channel_Name': 'TCDS COMPUTER EDUCATION',
#   'Channel_Id': 'UCVRi4KY1YQ6kNkKgR-pvk0A',
#   'Video_Id': 'aHtwv4q1ivU',
#   'Title': 'PYTHON / BASIC COMPUTER  LAB IN TAMIL [LAB-6]',
#   'Tags': ['how to open computer centre',
#    'diploma courses after 12th',
#    'top 10 computer education centres',
#    'best computer training centres',
#    'tcds computer',
#    'csri computer',
#    'tcds',
#    'csri',
#    'computer centres in tamilnadu',
#    'tcds computer education',
#    'csri computer education',
#    'computer in tamil',
#    'certificate course',
#    'PYTHON',
#    'How to use python',
#    'very easy learn in python',
#    'step by step learning python in tamil',
#    'python practice',
#    'python classes',
#    'basic python in tamil',
#    'how to learn pyhton',
#    'python tutorial'],
#   'Thumbnail': 'https://i.ytimg.com/vi/aHtwv4q1ivU/default.jpg',
#   'Description': 'In this video we teach you, about Computer Basics in Tamil with step by step method to learn easily.\n\nTo Support and motivate me please Subscribe, Share and Like this channel\n\nI Will also teach you high scope and valuable computer courses through this channel that are mentioned below :\n\nFREE JOB & BUSINESS ORIENTED COMPUTER COURSE with Government approved Course completed Certificate',
#   'Published_Date': None,
#   'Duration': 'PT14M44S',
#   'Views': '24',
#   'Likes': '0',
#   'Comments': '0',
#   'Favorite_count': '0',
#   'Definition': 'hd',
#   'Caption_status': 'false'},
#  {'Channel_Name': 'TCDS COMPUTER EDUCATION',
#   'Channel_Id': 'UCVRi4KY1YQ6kNkKgR-pvk0A',
#   'Video_Id': 'BEUQwz8dwTE',
#   'Title': 'MS POWERPOINT / BASIC COMPUTER CLASS IN TAMIL [CLASS-2]',
#   'Tags': ['how to start computer training centre',
#    'how to open computer centre',
#    'PowerPoint Tutorial',
#    'Presentation Tips',
#    'Slide Design',
#    'Microsoft PowerPoint',
#    'PowerPoint Tricks',
#    'PowerPoint Tips & Tricks',
#    'PowerPoint Hacks',
#    'PowerPoint Animation',
#    'PowerPoint Techniques',
#    'PowerPoint Templates',
#    'PowerPoint Masterclass',
#    'PowerPoint for Beginners',
#    'Advanced PowerPoint',
#    'basic computer class in tamil',
#    'PowerPoint Slide Examples',
#    'Presentation Design Ideas',
#    'Creative PowerPoint',
#    'Slide Deck Tips'],
#   'Thumbnail': 'https://i.ytimg.com/vi/BEUQwz8dwTE/default.jpg',
#   'Description': 'In this video we teach you, about Computer Basics in Tamil with step by step method to learn easily.\n\nTo Support and motivate me please Subscribe, Share and Like this channel\n\nI Will also teach you high scope and valuable computer courses through this channel that are mentioned below :\n\nFREE JOB & BUSINESS ORIENTED COMPUTER COURSE with Government approved Course completed Certificate',
#   'Published_Date': None,
#   'Duration': 'PT37M',
#   'Views': '96',
#   'Likes': '2',
#   'Comments': '0',
#   'Favorite_count': '0',
#   'Definition': 'hd',
#   'Caption_status': 'false'},
#  {'Channel_Name': 'TCDS COMPUTER EDUCATION',
#   'Channel_Id': 'UCVRi4KY1YQ6kNkKgR-pvk0A',
#   'Video_Id': 'dsuAHNQ2pjY',
#   'Title': 'PYTHON / BASIC COMPUTER  CLASS IN TAMIL [CLASS-11]',
#   'Tags': ['how to open computer centre',
#    'diploma courses after 12th',
#    'top 10 computer education centres',
#    'best computer training centres',
#    'tcds computer',
#    'csri computer',
#    'tcds',
#    'csri',
#    'computer centres in tamilnadu',
#    'tcds computer education',
#    'csri computer education',
#    'computer in tamil',
#    'certificate course',
#    'PYTHON',
#    'How to use python',
#    'very easy learn in python',
#    'step by step learning python in tamil',
#    'python practice',
#    'python classes',
#    'basic python in tamil',
#    'how to learn pyhton',
#    'python tutorial'],
#   'Thumbnail': 'https://i.ytimg.com/vi/dsuAHNQ2pjY/default.jpg',
#   'Description': 'In this video we teach you, about Computer Basics in Tamil with step by step method to learn easily.\n\nTo Support and motivate me please Subscribe, Share and Like this channel\n\nI Will also teach you high scope and valuable computer courses through this channel that are mentioned below :\n\nFREE JOB & BUSINESS ORIENTED COMPUTER COURSE with Government approved Course completed Certificate',
#   'Published_Date': None,
#   'Duration': 'PT11M45S',
#   'Views': '72',
#   'Likes': '0',
#   'Comments': '0',
#   'Favorite_count': '0',
#   'Definition': 'hd',
#   'Caption_status': 'false'},
#  {'Channel_Name': 'TCDS COMPUTER EDUCATION',
#   'Channel_Id': 'UCVRi4KY1YQ6kNkKgR-pvk0A',
#   'Video_Id': 'Dbm2GHXHN98',
#   'Title': 'MS POWERPOINT / BASIC COMPUTER LAB IN TAMIL [LAB-1]',
#   'Tags': ['how to start computer training centre',
#    'how to open computer centre',
#    'PowerPoint Tutorial',
#    'Presentation Tips',
#    'Slide Design',
#    'Microsoft PowerPoint',
#    'PowerPoint Tricks',
#    'PowerPoint Tips & Tricks',
#    'PowerPoint Hacks',
#    'PowerPoint Animation',
#    'PowerPoint Techniques',
#    'PowerPoint Templates',
#    'PowerPoint Masterclass',
#    'PowerPoint for Beginners',
#    'Advanced PowerPoint',
#    'basic computer class in tamil',
#    'PowerPoint Slide Examples',
#    'Presentation Design Ideas',
#    'Creative PowerPoint',
#    'Slide Deck Tips'],
#   'Thumbnail': 'https://i.ytimg.com/vi/Dbm2GHXHN98/default.jpg',
#   'Description': 'In this video we teach you, about Computer Basics in Tamil with step by step method to learn easily.\n\nTo Support and motivate me please Subscribe, Share and Like this channel\n\nI Will also teach you high scope and valuable computer courses through this channel that are mentioned below :\n\nFREE JOB & BUSINESS ORIENTED COMPUTER COURSE with Government approved Course completed Certificate',
#   'Published_Date': None,
#   'Duration': 'PT11M28S',
#   'Views': '82',
#   'Likes': '1',
#   'Comments': '0',
#   'Favorite_count': '0',
#   'Definition': 'hd',
#   'Caption_status': 'false'},
#  {'Channel_Name': 'TCDS COMPUTER EDUCATION',
#   'Channel_Id': 'UCVRi4KY1YQ6kNkKgR-pvk0A',
#   'Video_Id': 'oX3caV-LPuo',
#   'Title': 'PYTHON / BASIC COMPUTER  LAB IN TAMIL [LAB-5]',
#   'Tags': ['how to open computer centre',
#    'diploma courses after 12th',
#    'top 10 computer education centres',
#    'best computer training centres',
#    'tcds computer',
#    'csri computer',
#    'tcds',
#    'csri',
#    'computer centres in tamilnadu',
#    'tcds computer education',
#    'csri computer education',
#    'computer in tamil',
#    'certificate course',
#    'PYTHON',
#    'How to use python',
#    'very easy learn in python',
#    'step by step learning python in tamil',
#    'python practice',
#    'python classes',
#    'basic python in tamil',
#    'how to learn pyhton',
#    'python tutorial'],
#   'Thumbnail': 'https://i.ytimg.com/vi/oX3caV-LPuo/default.jpg',
#   'Description': 'In this video we teach you, about Computer Basics in Tamil with step by step method to learn easily.\n\nTo Support and motivate me please Subscribe, Share and Like this channel\n\nI Will also teach you high scope and valuable computer courses through this channel that are mentioned below :\n\nFREE JOB & BUSINESS ORIENTED COMPUTER COURSE with Government approved Course completed Certificate',
#   'Published_Date': None,
#   'Duration': 'PT13M22S',
#   'Views': '49',
#   'Likes': '1',
#   'Comments': '2',
#   'Favorite_count': '0',
#   'Definition': 'hd',
#   'Caption_status': 'false'},
#  {'Channel_Name': 'TCDS COMPUTER EDUCATION',
#   'Channel_Id': 'UCVRi4KY1YQ6kNkKgR-pvk0A',
#   'Video_Id': 'pjUipf59GtE',
#   'Title': 'MS POWERPOINT / BASIC COMPUTER CLASS IN TAMIL [CLASS-1]',
#   'Tags': ['how to start computer training centre',
#    'how to open computer centre',
#    'PowerPoint Tutorial',
#    'Presentation Tips',
#    'Slide Design',
#    'Microsoft PowerPoint',
#    'PowerPoint Tricks',
#    'PowerPoint Tips & Tricks',
#    'PowerPoint Hacks',
#    'PowerPoint Animation',
#    'PowerPoint Techniques',
#    'PowerPoint Templates',
#    'PowerPoint Masterclass',
#    'PowerPoint for Beginners',
#    'Advanced PowerPoint',
#    'basic computer class in tamil',
#    'PowerPoint Slide Examples',
#    'Presentation Design Ideas',
#    'Creative PowerPoint',
#    'Slide Deck Tips'],
#   'Thumbnail': 'https://i.ytimg.com/vi/pjUipf59GtE/default.jpg',
#   'Description': 'In this video we teach you, about Computer Basics in Tamil with step by step method to learn easily.\n\nTo Support and motivate me please Subscribe, Share and Like this channel\n\nI Will also teach you high scope and valuable computer courses through this channel that are mentioned below :\n\nFREE JOB & BUSINESS ORIENTED COMPUTER COURSE with Government approved Course completed Certificate',
#   'Published_Date': None,
#   'Duration': 'PT31M43S',
#   'Views': '140',
#   'Likes': '3',
#   'Comments': '0',
#   'Favorite_count': '0',
#   'Definition': 'hd',
#   'Caption_status': 'false'},
#  {'Channel_Name': 'TCDS COMPUTER EDUCATION',
#   'Channel_Id': 'UCVRi4KY1YQ6kNkKgR-pvk0A',
#   'Video_Id': 'FCIrXtA5bPw',
#   'Title': 'PYTHON / BASIC COMPUTER  CLASS IN TAMIL [CLASS-10]',
#   'Tags': ['how to open computer centre',
#    'diploma courses after 12th',
#    'top 10 computer education centres',
#    'best computer training centres',
#    'tcds computer',
#    'csri computer',
#    'tcds',
#    'csri',
#    'computer centres in tamilnadu',
#    'tcds computer education',
#    'csri computer education',
#    'computer in tamil',
#    'certificate course',
#    'PYTHON',
#    'How to use python',
#    'very easy learn in python',
#    'step by step learning python in tamil',
#    'python practice',
#    'python classes',
#    'basic python in tamil',
#    'how to learn pyhton',
#    'python tutorial'],
#   'Thumbnail': 'https://i.ytimg.com/vi/FCIrXtA5bPw/default.jpg',
#   'Description': 'In this video we teach you, about Computer Basics in Tamil with step by step method to learn easily.\n\nTo Support and motivate me please Subscribe, Share and Like this channel\n\nI Will also teach you high scope and valuable computer courses through this channel that are mentioned below :\n\nFREE JOB & BUSINESS ORIENTED COMPUTER COURSE with Government approved Course completed Certificate',
#   'Published_Date': None,
#   'Duration': 'PT17M44S',
#   'Views': '68',
#   'Likes': '0',
#   'Comments': '1',
#   'Favorite_count': '0',
#   'Definition': 'hd',
#   'Caption_status': 'false'},
#  {'Channel_Name': 'TCDS COMPUTER EDUCATION',
#   'Channel_Id': 'UCVRi4KY1YQ6kNkKgR-pvk0A',
#   'Video_Id': '9yAK2WWpK2U',
#   'Title': 'MS EXCEL / BASIC COMPUTER CLASS IN TAMIL [CLASS-15]',
#   'Tags': ['how to open computer centre',
#    'diploma courses after 12th',
#    'top 10 computer education centres',
#    'best computer training centres',
#    'tcds computer',
#    'csri computer',
#    'tcds',
#    'csri',
#    'computer centres in tamilnadu',
#    'tcds computer education',
#    'csri computer education',
#    'computer in tamil',
#    'certificate course',
#    'ms excel',
#    'how to use ms excel',
#    'very easy learn in ms excel',
#    'step by step learning ms excel in tamil',
#    'ms excel practice',
#    'ms excel classes',
#    'basic ms excel in tamil',
#    'how to learn ms excel'],
#   'Thumbnail': 'https://i.ytimg.com/vi/9yAK2WWpK2U/default.jpg',
#   'Description': 'In this video we teach you, about Computer Basics in Tamil with step by step method to learn easily.\n\nTo Support and motivate me please Subscribe, Share and Like this channel\n\nI Will also teach you high scope and valuable computer courses through this channel that are mentioned below :\n\nFREE JOB & BUSINESS ORIENTED COMPUTER COURSE with Government approved Course completed Certificate',
#   'Published_Date': None,
#   'Duration': 'PT31M27S',
#   'Views': '163',
#   'Likes': '2',
#   'Comments': '0',
#   'Favorite_count': '0',
#   'Definition': 'hd',
#   'Caption_status': 'false'},
#  {'Channel_Name': 'TCDS COMPUTER EDUCATION',
#   'Channel_Id': 'UCVRi4KY1YQ6kNkKgR-pvk0A',
#   'Video_Id': 'qjyw8E-kODI',
#   'Title': 'PYTHON / BASIC COMPUTER  LAB IN TAMIL [LAB-4]',
#   'Tags': ['how to open computer centre',
#    'diploma courses after 12th',
#    'top 10 computer education centres',
#    'best computer training centres',
#    'tcds computer',
#    'csri computer',
#    'tcds',
#    'csri',
#    'computer centres in tamilnadu',
#    'tcds computer education',
#    'csri computer education',
#    'computer in tamil',
#    'certificate course',
#    'PYTHON',
#    'How to use python',
#    'very easy learn in python',
#    'step by step learning python in tamil',
#    'python practice',
#    'python classes',
#    'basic python in tamil',
#    'how to learn pyhton',
#    'python tutorial'],
#   'Thumbnail': 'https://i.ytimg.com/vi/qjyw8E-kODI/default.jpg',
#   'Description': 'In this video we teach you, about Computer Basics in Tamil with step by step method to learn easily.\n\nTo Support and motivate me please Subscribe, Share and Like this channel\n\nI Will also teach you high scope and valuable computer courses through this channel that are mentioned below :\n\nFREE JOB & BUSINESS ORIENTED COMPUTER COURSE with Government approved Course completed Certificate',
#   'Published_Date': None,
#   'Duration': 'PT15M56S',
#   'Views': '87',
#   'Likes': '3',
#   'Comments': '2',
#   'Favorite_count': '0',
#   'Definition': 'hd',
#   'Caption_status': 'false'},
#  {'Channel_Name': 'TCDS COMPUTER EDUCATION',
#   'Channel_Id': 'UCVRi4KY1YQ6kNkKgR-pvk0A',
#   'Video_Id': 'FkgJgUoHMO8',
#   'Title': 'MS EXCEL / BASIC COMPUTER CLASS IN TAMIL [CLASS-19]',
#   'Tags': ['how to open computer centre',
#    'diploma courses after 12th',
#    'top 10 computer education centres',
#    'best computer training centres',
#    'tcds computer',
#    'csri computer',
#    'tcds',
#    'csri',
#    'computer centres in tamilnadu',
#    'tcds computer education',
#    'csri computer education',
#    'computer in tamil',
#    'certificate course',
#    'ms excel',
#    'how to use ms excel',
#    'very easy learn in ms excel',
#    'step by step learning ms excel in tamil',
#    'ms excel practice',
#    'ms excel classes',
#    'basic ms excel in tamil',
#    'how to learn ms excel'],
#   'Thumbnail': 'https://i.ytimg.com/vi/FkgJgUoHMO8/default.jpg',
#   'Description': 'In this video we teach you, about Computer Basics in Tamil with step by step method to learn easily.\n\nTo Support and motivate me please Subscribe, Share and Like this channel\n\nI Will also teach you high scope and valuable computer courses through this channel that are mentioned below :\n\nFREE JOB & BUSINESS ORIENTED COMPUTER COURSE with Government approved Course completed Certificate',
#   'Published_Date': None,
#   'Duration': 'PT43M31S',
#   'Views': '152',
#   'Likes': '2',
#   'Comments': '0',
#   'Favorite_count': '0',
#   'Definition': 'hd',
#   'Caption_status': 'false'},
#  {'Channel_Name': 'TCDS COMPUTER EDUCATION',
#   'Channel_Id': 'UCVRi4KY1YQ6kNkKgR-pvk0A',
#   'Video_Id': '-lkZJW-u6SE',
#   'Title': 'PYTHON / BASIC COMPUTER  CLASS IN TAMIL [CLASS-9]',
#   'Tags': ['how to open computer centre',
#    'diploma courses after 12th',
#    'top 10 computer education centres',
#    'best computer training centres',
#    'tcds computer',
#    'csri computer',
#    'tcds',
#    'csri',
#    'computer centres in tamilnadu',
#    'tcds computer education',
#    'csri computer education',
#    'computer in tamil',
#    'certificate course',
#    'PYTHON',
#    'How to use python',
#    'very easy learn in python',
#    'step by step learning python in tamil',
#    'python practice',
#    'python classes',
#    'basic python in tamil',
#    'how to learn pyhton',
#    'python tutorial'],
#   'Thumbnail': 'https://i.ytimg.com/vi/-lkZJW-u6SE/default.jpg',
#   'Description': 'In this video we teach you, about Computer Basics in Tamil with step by step method to learn easily.\n\nTo Support and motivate me please Subscribe, Share and Like this channel\n\nI Will also teach you high scope and valuable computer courses through this channel that are mentioned below :\n\nFREE JOB & BUSINESS ORIENTED COMPUTER COURSE with Government approved Course completed Certificate',
#   'Published_Date': None,
#   'Duration': 'PT16M16S',
#   'Views': '119',
#   'Likes': '0',
#   'Comments': '0',
#   'Favorite_count': '0',
#   'Definition': 'hd',
#   'Caption_status': 'false'},
#  {'Channel_Name': 'TCDS COMPUTER EDUCATION',
#   'Channel_Id': 'UCVRi4KY1YQ6kNkKgR-pvk0A',
#   'Video_Id': 'bZ2C7kBr2uo',
#   'Title': 'MS EXCEL / BASIC COMPUTER LAB IN TAMIL [LAB-18]',
#   'Tags': ['how to open computer centre',
#    'diploma courses after 12th',
#    'top 10 computer education centres',
#    'best computer training centres',
#    'tcds computer',
#    'csri computer',
#    'tcds',
#    'csri',
#    'computer centres in tamilnadu',
#    'tcds computer education',
#    'csri computer education',
#    'computer in tamil',
#    'certificate course',
#    'ms excel',
#    'how to use ms excel',
#    'very easy learn in ms excel',
#    'step by step learning ms excel in tamil',
#    'ms excel practice',
#    'ms excel classes',
#    'basic ms excel in tamil',
#    'how to learn ms excel'],
#   'Thumbnail': 'https://i.ytimg.com/vi/bZ2C7kBr2uo/default.jpg',
#   'Description': 'In this video we teach you, about Computer Basics in Tamil with step by step method to learn easily.\n\nTo Support and motivate me please Subscribe, Share and Like this channel\n\nI Will also teach you high scope and valuable computer courses through this channel that are mentioned below :\n\nFREE JOB & BUSINESS ORIENTED COMPUTER COURSE with Government approved Course completed Certificate',
#   'Published_Date': None,
#   'Duration': 'PT10M31S',
#   'Views': '50',
#   'Likes': '2',
#   'Comments': '0',
#   'Favorite_count': '0',
#   'Definition': 'hd',
#   'Caption_status': 'false'},
#  {'Channel_Name': 'TCDS COMPUTER EDUCATION',
#   'Channel_Id': 'UCVRi4KY1YQ6kNkKgR-pvk0A',
#   'Video_Id': '40iaejXZe44',
#   'Title': 'PYTHON / BASIC COMPUTER  LAB IN TAMIL [LAB-3]',
#   'Tags': ['how to open computer centre',
#    'diploma courses after 12th',
#    'top 10 computer education centres',
#    'best computer training centres',
#    'tcds computer',
#    'csri computer',
#    'tcds',
#    'csri',
#    'computer centres in tamilnadu',
#    'tcds computer education',
#    'csri computer education',
#    'computer in tamil',
#    'certificate course',
#    'PYTHON',
#    'How to use python',
#    'very easy learn in python',
#    'step by step learning python in tamil',
#    'python practice',
#    'python classes',
#    'basic python in tamil',
#    'how to learn pyhton',
#    'python tutorial'],
#   'Thumbnail': 'https://i.ytimg.com/vi/40iaejXZe44/default.jpg',
#   'Description': 'In this video we teach you, about Computer Basics in Tamil with step by step method to learn easily.\n\nTo Support and motivate me please Subscribe, Share and Like this channel\n\nI Will also teach you high scope and valuable computer courses through this channel that are mentioned below :\n\nFREE JOB & BUSINESS ORIENTED COMPUTER COURSE with Government approved Course completed Certificate',
#   'Published_Date': None,
#   'Duration': 'PT15M18S',
#   'Views': '44',
#   'Likes': '1',
#   'Comments': '0',
#   'Favorite_count': '0',
#   'Definition': 'hd',
#   'Caption_status': 'false'},
#  {'Channel_Name': 'TCDS COMPUTER EDUCATION',
#   'Channel_Id': 'UCVRi4KY1YQ6kNkKgR-pvk0A',
#   'Video_Id': 'dzGh8gLcmg4',
#   'Title': 'MS EXCEL / BASIC COMPUTER CLASS IN TAMIL [CLASS-18]',
#   'Tags': ['how to open computer centre',
#    'diploma courses after 12th',
#    'top 10 computer education centres',
#    'best computer training centres',
#    'tcds computer',
#    'csri computer',
#    'tcds',
#    'csri',
#    'computer centres in tamilnadu',
#    'tcds computer education',
#    'csri computer education',
#    'computer in tamil',
#    'certificate course',
#    'ms excel',
#    'how to use ms excel',
#    'very easy learn in ms excel',
#    'step by step learning ms excel in tamil',
#    'ms excel practice',
#    'ms excel classes',
#    'basic ms excel in tamil',
#    'how to learn ms excel'],
#   'Thumbnail': 'https://i.ytimg.com/vi/dzGh8gLcmg4/default.jpg',
#   'Description': 'In this video we teach you, about Computer Basics in Tamil with step by step method to learn easily.\n\nTo Support and motivate me please Subscribe, Share and Like this channel\n\nI Will also teach you high scope and valuable computer courses through this channel that are mentioned below :\n\nFREE JOB & BUSINESS ORIENTED COMPUTER COURSE with Government approved Course completed Certificate',
#   'Published_Date': None,
#   'Duration': 'PT25M44S',
#   'Views': '257',
#   'Likes': '4',
#   'Comments': '0',
#   'Favorite_count': '0',
#   'Definition': 'hd',
#   'Caption_status': 'false'},
#  {'Channel_Name': 'TCDS COMPUTER EDUCATION',
#   'Channel_Id': 'UCVRi4KY1YQ6kNkKgR-pvk0A',
#   'Video_Id': 'ZkWJRBno-KE',
#   'Title': 'PYTHON / BASIC COMPUTER  CLASS IN TAMIL [CLASS-8]',
#   'Tags': ['how to open computer centre',
#    'diploma courses after 12th',
#    'top 10 computer education centres',
#    'best computer training centres',
#    'tcds computer',
#    'csri computer',
#    'tcds',
#    'csri',
#    'computer centres in tamilnadu',
#    'tcds computer education',
#    'csri computer education',
#    'computer in tamil',
#    'certificate course',
#    'PYTHON',
#    'How to use python',
#    'very easy learn in python',
#    'step by step learning python in tamil',
#    'python practice',
#    'python classes',
#    'basic python in tamil',
#    'how to learn pyhton',
#    'python tutorial'],
#   'Thumbnail': 'https://i.ytimg.com/vi/ZkWJRBno-KE/default.jpg',
#   'Description': 'In this video we teach you, about Computer Basics in Tamil with step by step method to learn easily.\n\nTo Support and motivate me please Subscribe, Share and Like this channel\n\nI Will also teach you high scope and valuable computer courses through this channel that are mentioned below :\n\nFREE JOB & BUSINESS ORIENTED COMPUTER COURSE with Government approved Course completed Certificate',
#   'Published_Date': None,
#   'Duration': 'PT15M59S',
#   'Views': '49',
#   'Likes': '0',
#   'Comments': '0',
#   'Favorite_count': '0',
#   'Definition': 'hd',
#   'Caption_status': 'false'},
#  {'Channel_Name': 'TCDS COMPUTER EDUCATION',
#   'Channel_Id': 'UCVRi4KY1YQ6kNkKgR-pvk0A',
#   'Video_Id': 't2linI2w2b8',
#   'Title': 'MS EXCEL / BASIC COMPUTER LAB IN TAMIL [LAB-17]',
#   'Tags': ['how to open computer centre',
#    'diploma courses after 12th',
#    'top 10 computer education centres',
#    'best computer training centres',
#    'tcds computer',
#    'csri computer',
#    'tcds',
#    'csri',
#    'computer centres in tamilnadu',
#    'tcds computer education',
#    'csri computer education',
#    'computer in tamil',
#    'certificate course',
#    'ms excel',
#    'how to use ms excel',
#    'very easy learn in ms excel',
#    'step by step learning ms excel in tamil',
#    'ms excel practice',
#    'ms excel classes',
#    'basic ms excel in tamil',
#    'how to learn ms excel'],
#   'Thumbnail': 'https://i.ytimg.com/vi/t2linI2w2b8/default.jpg',
#   'Description': 'In this video we teach you, about Computer Basics in Tamil with step by step method to learn easily.\n\nTo Support and motivate me please Subscribe, Share and Like this channel\n\nI Will also teach you high scope and valuable computer courses through this channel that are mentioned below :\n\nFREE JOB & BUSINESS ORIENTED COMPUTER COURSE with Government approved Course completed Certificate',
#   'Published_Date': None,
#   'Duration': 'PT18M3S',
#   'Views': '183',
#   'Likes': '1',
#   'Comments': '0',
#   'Favorite_count': '0',
#   'Definition': 'hd',
#   'Caption_status': 'false'},
#  {'Channel_Name': 'TCDS COMPUTER EDUCATION',
#   'Channel_Id': 'UCVRi4KY1YQ6kNkKgR-pvk0A',
#   'Video_Id': 'dZbIChinTw4',
#   'Title': 'PYTHON / BASIC COMPUTER  CLASS IN TAMIL [CLASS-7]',
#   'Tags': ['how to open computer centre',
#    'diploma courses after 12th',
#    'top 10 computer education centres',
#    'best computer training centres',
#    'tcds computer',
#    'csri computer',
#    'tcds',
#    'csri',
#    'computer centres in tamilnadu',
#    'tcds computer education',
#    'csri computer education',
#    'computer in tamil',
#    'certificate course',
#    'PYTHON',
#    'How to use python',
#    'very easy learn in python',
#    'step by step learning python in tamil',
#    'python practice',
#    'python classes',
#    'basic python in tamil',
#    'how to learn pyhton',
#    'python tutorial'],
#   'Thumbnail': 'https://i.ytimg.com/vi/dZbIChinTw4/default.jpg',
#   'Description': 'In this video we teach you, about Computer Basics in Tamil with step by step method to learn easily.\n\nTo Support and motivate me please Subscribe, Share and Like this channel\n\nI Will also teach you high scope and valuable computer courses through this channel that are mentioned below :\n\nFREE JOB & BUSINESS ORIENTED COMPUTER COURSE with Government approved Course completed Certificate',
#   'Published_Date': None,
#   'Duration': 'PT20M29S',
#   'Views': '86',
#   'Likes': '2',
#   'Comments': '0',
#   'Favorite_count': '0',
#   'Definition': 'hd',
#   'Caption_status': 'false'},
#  {'Channel_Name': 'TCDS COMPUTER EDUCATION',
#   'Channel_Id': 'UCVRi4KY1YQ6kNkKgR-pvk0A',
#   'Video_Id': 'Ox9tCa8LtBs',
#   'Title': 'MS EXCEL / BASIC COMPUTER CLASS IN TAMIL [CLASS-17]',
#   'Tags': ['how to open computer centre',
#    'diploma courses after 12th',
#    'top 10 computer education centres',
#    'best computer training centres',
#    'tcds computer',
#    'csri computer',
#    'tcds',
#    'csri',
#    'computer centres in tamilnadu',
#    'tcds computer education',
#    'csri computer education',
#    'computer in tamil',
#    'certificate course',
#    'ms excel',
#    'how to use ms excel',
#    'very easy learn in ms excel',
#    'step by step learning ms excel in tamil',
#    'ms excel practice',
#    'ms excel classes',
#    'basic ms excel in tamil',
#    'how to learn ms excel'],
#   'Thumbnail': 'https://i.ytimg.com/vi/Ox9tCa8LtBs/default.jpg',
#   'Description': 'In this video we teach you, about Computer Basics in Tamil with step by step method to learn easily.\n\nTo Support and motivate me please Subscribe, Share and Like this channel\n\nI Will also teach you high scope and valuable computer courses through this channel that are mentioned below :\n\nFREE JOB & BUSINESS ORIENTED COMPUTER COURSE with Government approved Course completed Certificate',
#   'Published_Date': None,
#   'Duration': 'PT27M24S',
#   'Views': '184',
#   'Likes': '4',
#   'Comments': '0',
#   'Favorite_count': '0',
#   'Definition': 'hd',
#   'Caption_status': 'false'},
#  {'Channel_Name': 'TCDS COMPUTER EDUCATION',
#   'Channel_Id': 'UCVRi4KY1YQ6kNkKgR-pvk0A',
#   'Video_Id': 'nVVr-bNWe6c',
#   'Title': 'PYTHON / BASIC COMPUTER  CLASS IN TAMIL [CLASS-6]',
#   'Tags': ['how to open computer centre',
#    'diploma courses after 12th',
#    'top 10 computer education centres',
#    'best computer training centres',
#    'tcds computer',
#    'csri computer',
#    'tcds',
#    'csri',
#    'computer centres in tamilnadu',
#    'tcds computer education',
#    'csri computer education',
#    'computer in tamil',
#    'certificate course',
#    'PYTHON',
#    'How to use python',
#    'very easy learn in python',
#    'step by step learning python in tamil',
#    'python practice',
#    'python classes',
#    'basic python in tamil',
#    'how to learn pyhton',
#    'python tutorial'],
#   'Thumbnail': 'https://i.ytimg.com/vi/nVVr-bNWe6c/default.jpg',
# ...
#   'Video_Id': 'mYCHxPsIMO0',
#   'Title': 'HOW TO START COMPUTER TRAINING CENTRE | TCDS & CSRI COMPUTER EDUCATION CENTRE',
#   'Tags': ['how to start computer training centre',
#    'how to open computer centre',
#    'how to get approval for computer education',
#    'how to start computer training institute',
#    'how to start computer institute',
#    'computer education centre',
#    'computer course after 10th',
#    'top 10 computer education centres',
#    'best computer training centres',
#    'tcds computer',
#    'csri computer',
#    'tcds',
#    'csri',
#    'computer institute franchise',
#    'computer centres in tamilnadu',
#    'tcds computer education',
#    'csri computer education'],
#   'Thumbnail': 'https://i.ytimg.com/vi/mYCHxPsIMO0/default.jpg',
#   'Description': 'WANTED IMMEDIATELY : \n\nRegistration Link for STAFF/ DEALERS / FRANCHISE / INVESTORS https://forms.gle/jUpg3vTTvmK2pqtY6\n\nDetail Video to Start New COMPUTER EDUCATION CENTRE \n1. TCDS : https://youtu.be/ihVMY7FHebM \n2. CSRI : https://youtu.be/oswuH7h8Dwo \n\nDetail Video for ECPLAZA.COM (P) Ltd., DEALER. \nhttps://youtu.be/nYnTAE8BxgA\n\n\n#TCDScomputereducation #CSRIcomputereducation #EcPlazaTv\n\nWith Best Regards \nEC PLAZA COM (P) Ltd., \nTCDS COMPUTER EDUCATION \nCSRI COMPUTER EDUCATION...',
#   'Published_Date': None,
#   'Duration': 'PT1M9S',
#   'Views': '268',
#   'Likes': '2',
#   'Comments': '0',
#   'Favorite_count': '0',
#   'Definition': 'hd',
#   'Caption_status': 'false'},
#  {'Channel_Name': 'TCDS COMPUTER EDUCATION',
#   'Channel_Id': 'UCVRi4KY1YQ6kNkKgR-pvk0A',
#   'Video_Id': 'DQ7__f78sUc',
#   'Title': 'FRANCHISE WANTED ALL OVER TAMILNADU...',
#   'Tags': ['how to start computer training centre',
#    'how to open computer centre',
#    'how to get approval for computer education',
#    'how to start computer training institute',
#    'how to start computer institute',
#    'computer education centre',
#    'computer course after 10th',
#    'top 10 computer education centres',
#    'best computer training centres',
#    'tcds computer',
#    'csri computer',
#    'tcds',
#    'csri',
#    'computer institute franchise',
#    'computer centres in tamilnadu',
#    'tcds computer education',
#    'csri computer education'],
#   'Thumbnail': 'https://i.ytimg.com/vi/DQ7__f78sUc/default.jpg',
#   'Description': 'WANTED IMMEDIATELY : \n\nFRANCHISE ENQUIRY : \nhttps://forms.gle/jUpg3vTTvmK2pqtY6\n\nDetail Video to Start New COMPUTER EDUCATION CENTRE \n1. TCDS : https://youtu.be/ihVMY7FHebM \n2. CSRI : https://youtu.be/oswuH7h8Dwo \n\nDetail Video for ECPLAZA.COM (P) Ltd., DEALER. \nhttps://youtu.be/nYnTAE8BxgA\n\n\n#TCDScomputereducation #CSRIcomputereducation #EcPlazaTv\n\nWith Best Regards \nEC PLAZA COM (P) Ltd., \nTCDS COMPUTER EDUCATION \nCSRI COMPUTER EDUCATION...',
#   'Published_Date': None,
#   'Duration': 'PT5M44S',
#   'Views': '170',
#   'Likes': '2',
#   'Comments': '0',
#   'Favorite_count': '0',
#   'Definition': 'hd',
#   'Caption_status': 'false'},
#  {'Channel_Name': 'TCDS COMPUTER EDUCATION',
#   'Channel_Id': 'UCVRi4KY1YQ6kNkKgR-pvk0A',
#   'Video_Id': 'XvxKJELxDSY',
#   'Title': 'STAFF WANTED IMMEDIATELY',
#   'Tags': ['how to start computer training centre',
#    'how to open computer centre',
#    'how to get approval for computer education',
#    'how to start computer training institute',
#    'how to start computer institute',
#    'computer education centre',
#    'computer course after 10th',
#    'top 10 computer education centres',
#    'best computer training centres',
#    'tcds computer',
#    'csri computer',
#    'tcds',
#    'csri',
#    'computer institute franchise',
#    'computer centres in tamilnadu',
#    'tcds computer education',
#    'csri computer education'],
#   'Thumbnail': 'https://i.ytimg.com/vi/XvxKJELxDSY/default.jpg',
#   'Description': 'WANTED IMMEDIATELY : \n\nRegistration Link for STAFF/ DEALERS / FRANCHISE / INVESTORS https://forms.gle/jUpg3vTTvmK2pqtY6\n\nDetail Video to Start New COMPUTER EDUCATION CENTRE \n1. TCDS : https://youtu.be/ihVMY7FHebM \n2. CSRI : https://youtu.be/oswuH7h8Dwo \n\nDetail Video for ECPLAZA.COM (P) Ltd., DEALER. \nhttps://youtu.be/nYnTAE8BxgA\n\n\n#TCDScomputereducation #CSRIcomputereducation #EcPlazaTv\n\nWith Best Regards \nEC PLAZA COM (P) Ltd., \nTCDS COMPUTER EDUCATION \nCSRI COMPUTER EDUCATION...',
#   'Published_Date': None,
#   'Duration': 'PT3M12S',
#   'Views': '152',
#   'Likes': '4',
#   'Comments': '0',
#   'Favorite_count': '0',
#   'Definition': 'hd',
#   'Caption_status': 'false'},
#  {'Channel_Name': 'TCDS COMPUTER EDUCATION',
#   'Channel_Id': 'UCVRi4KY1YQ6kNkKgR-pvk0A',
#   'Video_Id': 'W3QdUBkSh1Q',
#   'Title': "Please don't Miss Our District wise Meeting & Interview | TCDS | CSRI | ECPLAZA",
#   'Tags': ['how to start computer training centre',
#    'how to open computer centre',
#    'how to get approval for computer education',
#    'how to start computer training institute',
#    'how to start computer institute',
#    'computer education centre',
#    'computer course after 10th',
#    'top 10 computer education centres',
#    'best computer training centres',
#    'tcds computer',
#    'csri computer',
#    'tcds',
#    'csri',
#    'computer institute franchise',
#    'computer centres in tamilnadu',
#    'tcds computer education',
#    'csri computer education',
#    'computer in tamil'],
#   'Thumbnail': 'https://i.ytimg.com/vi/W3QdUBkSh1Q/default.jpg',
#   'Description': '#TCDScomputereducation\n#CSRIcomputereducation\n#ecplazaDGM \n#ecplazaAGM \n#ecplazaDO\n\nRegistration Link for STAFF / DEALER / FRANCHISE\nhttps://forms.gle/jUpg3vTTvmK2pqtY6 \n\nGENERAL DETAILS FOR ECPLAZA BUSINESS VIDEO :\nhttps://youtu.be/0-8qWtHTOTg \n\nDetail Videos for DEALERS \n\n1. DGM : https://youtu.be/jbOQ0FZM0Rg \n2. AGM : https://youtu.be/BKix-MgDmFE \n3. DO : https://youtu.be/yCBkLD98AR4 \n\nDetail Video to Start New COMPUTER EDUCATION CENTRE\n\n1. TCDS  : https://youtu.be/ihVMY7FHebM\n2. CSRI   : https://youtu.be/oswuH7h8Dwo\n\nECPLAZA CUSTOMER APP INSTALLATION PROCEDURE VIDEO LINK : https://youtu.be/bBnscsXhssk \n\n1. EC PLAZA CUSTOMER MOBILE APP : PART-1 \n    https://youtu.be/xemxJop_MmY \n\n2. EC PLAZA CUSTOMER MOBILE APP : PART-2 \n    https://youtu.be/lS3Umg47c5Y \n\n3. EC PLAZA CUSTOMER MOBILE APP : PART-3 \n    https://youtu.be/ki11Xq65tv8 \n\n4. EC PLAZA CUSTOMER MOBILE APP : PART-4 \n    https://youtu.be/o3aIrFATIbQ \n\n5. EC PLAZA CUSTOMER MOBILE APP : PART-5 \n    https://youtu.be/OfMxTv07thQ \n\n\nWith Best Regards \n\nEC PLAZA COM PVT. LTD.,\nTCDS COMPUTER EDUCATION \nCSRI COMPUTER EDUCATION...',
#   'Published_Date': None,
#   'Duration': 'PT2M54S',
#   'Views': '81',
#   'Likes': '2',
#   'Comments': '0',
#   'Favorite_count': '0',
#   'Definition': 'hd',
#   'Caption_status': 'false'},
#  {'Channel_Name': 'TCDS COMPUTER EDUCATION',
#   'Channel_Id': 'UCVRi4KY1YQ6kNkKgR-pvk0A',
#   'Video_Id': 'M7DjoEJ78Ic',
#   'Title': 'How to Start TCDS Computer Centre Franchise | Procedure to Open TCDS Computer Institute',
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/M7DjoEJ78Ic/default.jpg',
#   'Description': 'WANTED IMMEDIATELY : \n\nRegistration Link for STAFF/ DEALERS / FRANCHISE / INVESTORS https://forms.gle/jUpg3vTTvmK2pqtY6\n\nDownload the EcPlaza Customer App from here \nhttps://ecplaza.co/url/C411385 \n\nDetail Video to Start New COMPUTER EDUCATION CENTRE \n1. TCDS : https://youtu.be/ihVMY7FHebM \n2. CSRI : https://youtu.be/oswuH7h8Dwo \n\nDetail Video for ECPLAZA.COM (P) Ltd., DEALER. \nhttps://youtu.be/nYnTAE8BxgA\n\n#TCDScomputereducation #CSRIcomputereducation #EcPlazaTv\n\nWith Best Regards \nEC PLAZA COM (P) Ltd., \nTCDS COMPUTER EDUCATION \nCSRI COMPUTER EDUCATION...',
#   'Published_Date': None,
#   'Duration': 'PT6M34S',
#   'Views': '5326',
#   'Likes': '75',
#   'Comments': '3',
#   'Favorite_count': '0',
#   'Definition': 'hd',
#   'Caption_status': 'false'},
#  {'Channel_Name': 'TCDS COMPUTER EDUCATION',
#   'Channel_Id': 'UCVRi4KY1YQ6kNkKgR-pvk0A',
#   'Video_Id': '4QoiAWBXLtw',
#   'Title': 'WANTED IMMEDIATELY ( STAFF / DEALERS / FRANCHISE )',
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/4QoiAWBXLtw/default.jpg',
#   'Description': 'WANTED IMMEDIATELY : \n\nRegistration Link for STAFF/ DEALERS / FRANCHISE / INVESTORS https://forms.gle/jUpg3vTTvmK2pqtY6\n\nDownload the EcPlaza Customer App from here \nhttps://ecplaza.co/url/C411385 \n\nDetail Video to Start New COMPUTER EDUCATION CENTRE \n1. TCDS : https://youtu.be/ihVMY7FHebM \n2. CSRI : https://youtu.be/oswuH7h8Dwo \n\nDetail Video for ECPLAZA.COM (P) Ltd., DEALER. \nhttps://youtu.be/nYnTAE8BxgA\n\n#TCDScomputereducation #CSRIcomputereducation #EcPlazaTv\n\nWith Best Regards \nEC PLAZA COM (P) Ltd., \nTCDS COMPUTER EDUCATION \nCSRI COMPUTER EDUCATION...',
#   'Published_Date': None,
#   'Duration': 'PT46S',
#   'Views': '67',
#   'Likes': '2',
#   'Comments': '0',
#   'Favorite_count': '0',
#   'Definition': 'hd',
#   'Caption_status': 'false'},
#  {'Channel_Name': 'TCDS COMPUTER EDUCATION',
#   'Channel_Id': 'UCVRi4KY1YQ6kNkKgR-pvk0A',
#   'Video_Id': 'sWWkzert6Kg',
#   'Title': 'JOB | BUSINESS |DEALERS | FRANCHISE',
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/sWWkzert6Kg/default.jpg',
#   'Description': 'WANTED IMMEDIATELY : \n\nRegistration Link for STAFF/ DEALERS / FRANCHISE / INVESTORS https://forms.gle/jUpg3vTTvmK2pqtY6\n\nDownload the EcPlaza Customer App from here \nhttps://ecplaza.co/url/C411385 \n\nDetail Video to Start New COMPUTER EDUCATION CENTRE \n1. TCDS : https://youtu.be/ihVMY7FHebM \n2. CSRI : https://youtu.be/oswuH7h8Dwo \n\nDetail Video for ECPLAZA.COM (P) Ltd., DEALER. \nhttps://youtu.be/nYnTAE8BxgA\n\n#TCDScomputereducation #CSRIcomputereducation #EcPlazaTv\n\nWith Best Regards \nEC PLAZA COM (P) Ltd., \nTCDS COMPUTER EDUCATION \nCSRI COMPUTER EDUCATION...',
#   'Published_Date': None,
#   'Duration': 'PT31S',
#   'Views': '36',
#   'Likes': '2',
#   'Comments': '0',
#   'Favorite_count': '0',
#   'Definition': 'hd',
#   'Caption_status': 'false'},
#  {'Channel_Name': 'TCDS COMPUTER EDUCATION',
#   'Channel_Id': 'UCVRi4KY1YQ6kNkKgR-pvk0A',
#   'Video_Id': 'ihVMY7FHebM',
#   'Title': 'HOW TO START COMPUTER CENTRE | COMPUTER TRAINING CENTRE | COMPUTER INSTITUTE | COMPUTER EDUCATION',
#   'Tags': ['how to start new computer centre',
#    'how to open computer training institute',
#    'how to get approval for computer education centre',
#    'computer training centre in tamil'],
#   'Thumbnail': 'https://i.ytimg.com/vi/ihVMY7FHebM/default.jpg',
#   'Description': 'HOW TO START COMPUTER CENTRE | COMPUTER TRAINING CENTRE | COMPUTER INSTITUTE | COMPUTER EDUCATION',
#   'Published_Date': None,
#   'Duration': 'PT7M24S',
#   'Views': '1097',
#   'Likes': '13',
#   'Comments': '1',
#   'Favorite_count': '0',
#   'Definition': 'hd',
#   'Caption_status': 'false'},
#  {'Channel_Name': 'TCDS COMPUTER EDUCATION',
#   'Channel_Id': 'UCVRi4KY1YQ6kNkKgR-pvk0A',
#   'Video_Id': 'Z00Sot0aRjI',
#   'Title': 'COMPUTER EDUCATION | NEW BUSINESS | A SUCCESSFUL FUTURE BUSINESS.',
#   'Tags': ['computer centre', 'computer education', 'new business'],
#   'Thumbnail': 'https://i.ytimg.com/vi/Z00Sot0aRjI/default.jpg',
#   'Description': 'All Computer Center owners can think about a new Successful Permanent future Business.  \n\n1. For DGM Dealer Video  :\n     https://youtu.be/jbOQ0FZM0Rg\n\n2. For AGM Dealer Video  :\n     https://youtu.be/BKix-MgDmFE\n\n3. For DO Dealer Video     :\n     https://youtu.be/yCBkLD98AR4\n\n\nIf you are Interested please Register your details in the below Link :\n\nhttps://forms.gle/jUpg3vTTvmK2pqtY6\n\nThe other details will be send to your Whatsapp.\n\n#computercentre\n#newecplazabusiness\n#ecplazadgm\n#ecplazaagm\n#ecplazado',
#   'Published_Date': None,
#   'Duration': 'PT3M25S',
#   'Views': '1747',
#   'Likes': '13',
#   'Comments': '0',
#   'Favorite_count': '0',
#   'Definition': 'hd',
#   'Caption_status': 'false'},
#  {'Channel_Name': 'TCDS COMPUTER EDUCATION',
#   'Channel_Id': 'UCVRi4KY1YQ6kNkKgR-pvk0A',
#   'Video_Id': '42JvaVtNGpE',
#   'Title': 'New Courses @ TCDS Computer Education, how to earn money, money making idea, best earning idea',
#   'Tags': ['money making idea',
#    'best earning app',
#    'additional income for csc',
#    'money making ideas from home',
#    'money making ideas for students',
#    'how to earn money online without investment',
#    'how to earn money online'],
#   'Thumbnail': 'https://i.ytimg.com/vi/42JvaVtNGpE/default.jpg',
#   'Description': '',
#   'Published_Date': None,
#   'Duration': 'PT3M32S',
#   'Views': '1615',
#   'Likes': '36',
#   'Comments': '2',
#   'Favorite_count': '0',
#   'Definition': 'hd',
#   'Caption_status': 'false'},
#  {'Channel_Name': 'TCDS COMPUTER EDUCATION',
#   'Channel_Id': 'UCVRi4KY1YQ6kNkKgR-pvk0A',
#   'Video_Id': 'c4sp-8VXrEY',
#   'Title': 'HOW TO START COMPUTER TRAINING CENTER',
#   'Tags': ['how to start computer Training Center',
#    'computer Institute',
#    'computer Institute in tamil'],
#   'Thumbnail': 'https://i.ytimg.com/vi/c4sp-8VXrEY/default.jpg',
#   'Description': 'HOW TO START COMPUTER TRAINING CENTRE',
#   'Published_Date': None,
#   'Duration': 'PT4M21S',
#   'Views': '330',
#   'Likes': '6',
#   'Comments': '0',
#   'Favorite_count': '0',
#   'Definition': 'hd',
#   'Caption_status': 'false'},
#  {'Channel_Name': 'TCDS COMPUTER EDUCATION',
#   'Channel_Id': 'UCVRi4KY1YQ6kNkKgR-pvk0A',
#   'Video_Id': '-4sZAnuLSXI',
#   'Title': 'தமிழக அஞ்சல் துறையில் 3162 GDS பணி',
#   'Tags': ['Post Office Job', 'GDS Job in Tamilnadu Postal Department'],
#   'Thumbnail': 'https://i.ytimg.com/vi/-4sZAnuLSXI/default.jpg',
#   'Description': 'தமிழக அஞ்சல் துறையில் 3162 GDA பணி\n\n#TNpostalJobs\n#GDSpostsinTN',
#   'Published_Date': None,
#   'Duration': 'PT2M',
#   'Views': '92',
#   'Likes': '9',
#   'Comments': '0',
#   'Favorite_count': '0',
#   'Definition': 'hd',
#   'Caption_status': 'false'},
#  {'Channel_Name': 'TCDS COMPUTER EDUCATION',
#   'Channel_Id': 'UCVRi4KY1YQ6kNkKgR-pvk0A',
#   'Video_Id': 'Z1G8XepBDT4',
#   'Title': 'MONEY / JOB / BUSINESS',
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/Z1G8XepBDT4/default.jpg',
#   'Description': '',
#   'Published_Date': None,
#   'Duration': 'PT4M5S',
#   'Views': '39',
#   'Likes': '1',
#   'Comments': '0',
#   'Favorite_count': '0',
#   'Definition': 'hd',
#   'Caption_status': 'false'},
#  {'Channel_Name': 'TCDS COMPUTER EDUCATION',
#   'Channel_Id': 'UCVRi4KY1YQ6kNkKgR-pvk0A',
#   'Video_Id': 'kSBqcGuMxeg',
#   'Title': 'கல்லூரிகளுக்கு லட்ச்சத்திலும் கோடியிலும் வருமான வாய்ப்பை அள்ளித்தரும் இந்தியாவின் No.1MobileApp.',
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/kSBqcGuMxeg/default.jpg',
#   'Description': 'Ecplaza.com (P) Ltd.,\nwww.ecplaza.co\nCell : 63855 63945',
#   'Published_Date': None,
#   'Duration': 'PT5M10S',
#   'Views': '66',
#   'Likes': '3',
#   'Comments': '0',
#   'Favorite_count': '0',
#   'Definition': 'hd',
#   'Caption_status': 'false'},
#  {'Channel_Name': 'TCDS COMPUTER EDUCATION',
#   'Channel_Id': 'UCVRi4KY1YQ6kNkKgR-pvk0A',
#   'Video_Id': 'XXCimlXY1MM',
#   'Title': 'கல்லூரிகளுக்கு லட்ச்சத்திலும் கோடியிலும் வருமான வாய்ப்பை அள்ளித்தரும் இந்தியாவின் No.1 Mobile App.',
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/XXCimlXY1MM/default.jpg',
#   'Description': 'Ecplaza.com (P) Ltd.,\nwww.ecplaza.co',
#   'Published_Date': None,
#   'Duration': 'PT4M',
#   'Views': '42',
#   'Likes': '0',
#   'Comments': '0',
#   'Favorite_count': '0',
#   'Definition': 'hd',
#   'Caption_status': 'false'},
#  {'Channel_Name': 'TCDS COMPUTER EDUCATION',
#   'Channel_Id': 'UCVRi4KY1YQ6kNkKgR-pvk0A',
#   'Video_Id': '0gVsNO1Gusg',
#   'Title': 'COMPUTER EDUCATION',
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/0gVsNO1Gusg/default.jpg',
#   'Description': 'FRANCHISE WANTED FOR COMPUTER EDUCATION',
#   'Published_Date': None,
#   'Duration': 'PT3M47S',
#   'Views': '290',
#   'Likes': '11',
#   'Comments': '1',
#   'Favorite_count': '0',
#   'Definition': 'sd',
#   'Caption_status': 'false'},
#  {'Channel_Name': 'TCDS COMPUTER EDUCATION',
#   'Channel_Id': 'UCVRi4KY1YQ6kNkKgR-pvk0A',
#   'Video_Id': 'YpIf_2wOu7A',
#   'Title': 'COMPUTER EDUCATION',
#   'Tags': None,
#   'Thumbnail': 'https://i.ytimg.com/vi/YpIf_2wOu7A/default.jpg',
#   'Description': 'DEVELOPMENT OFFICERS WANTED',
#   'Published_Date': None,
#   'Duration': 'PT48S',
#   'Views': '371',
#   'Likes': '8',
#   'Comments': '0',
#   'Favorite_count': '0',
#   'Definition': 'sd',
#   'Caption_status': 'false'}]

# %%
len(video_details)
# Out:
# 168

# %%
# get comment information
def get_comment_info(video_ids):
    Comment_data=[]
    try:
        for video_id in video_ids:
            request = youtube.commentThreads().list(
                part = "snippet",
                videoId = video_id,
                maxResults = 50,
            )

            response = request.execute()

            for item in response['items']:
                data = dict(Comment_Id = item['snippet']['topLevelComment']['id'],
                            Video_Id = item['snippet']['topLevelComment']['snippet']['videoId'],
                            Comment_Text = item['snippet']['topLevelComment']['snippet']['textDisplay'],
                            Comment_Author = item['snippet']['topLevelComment']['snippet']['authorDisplayName'],
                            Comment_Published = item['snippet']['topLevelComment']['snippet']['publishedAt'])

                Comment_data.append(data)

    except:
        pass
    return Comment_data

# %%
Comment_details = get_comment_info(Video_Ids)

# %%
len(Comment_details)
# Out:
# 113

# %%
Comment_details
# Out:
# [{'Comment_Id': 'UgzEl8LzcQkmWcBZEjh4AaABAg',
#   'Video_Id': 'd2Ls52t5KpA',
#   'Comment_Text': 'Nice',
#   'Comment_Author': '@newtamiltech2221',
#   'Comment_Published': '2024-05-23T17:32:10Z'},
#  {'Comment_Id': 'UgyvvH0jF9zPEeHypRd4AaABAg',
#   'Video_Id': 'HlOfh2qHC6k',
#   'Comment_Text': 'Super amazing nice',
#   'Comment_Author': '@MANITAMILMOVIES',
#   'Comment_Published': '2024-05-09T11:57:51Z'},
#  {'Comment_Id': 'UgzjUIj04ZOYeO8w1G14AaABAg',
#   'Video_Id': 'LYPlSgSTLq4',
#   'Comment_Text': 'Thank you soo much your PYTHON / BASIC COMPUTER CLASS IN TAMIL [CLASS-13]',
#   'Comment_Author': '@MANITAMILMOVIES',
#   'Comment_Published': '2024-04-26T19:40:33Z'},
#  {'Comment_Id': 'UgzSg6yhCSBe459Rtd14AaABAg',
#   'Video_Id': '52uOR0kFRac',
#   'Comment_Text': 'I am 1st watching video',
#   'Comment_Author': '@MANITAMILMOVIES',
#   'Comment_Published': '2024-04-22T13:31:38Z'},
#  {'Comment_Id': 'UgxzRrW8mUsOM9Sr6al4AaABAg',
#   'Video_Id': 'oX3caV-LPuo',
#   'Comment_Text': 'I will like all YouTube videos',
#   'Comment_Author': '@MANITAMILMOVIES',
#   'Comment_Published': '2024-04-08T17:23:08Z'},
#  {'Comment_Id': 'UgzsNclDW32aw58qkBB4AaABAg',
#   'Video_Id': 'oX3caV-LPuo',
#   'Comment_Text': 'Thanks so much',
#   'Comment_Author': '@MANITAMILMOVIES',
#   'Comment_Published': '2024-04-08T17:22:36Z'},
#  {'Comment_Id': 'UgwlXNPZa_1baV5OHON4AaABAg',
#   'Video_Id': 'FCIrXtA5bPw',
#   'Comment_Text': 'I need more like this 🤩🤩🔥 please put more videos 🙇🙏🙏❤️.',
#   'Comment_Author': '@punithavalli1306',
#   'Comment_Published': '2024-04-05T14:34:18Z'},
#  {'Comment_Id': 'UgyV6Ag3O9VQVO1y4oh4AaABAg',
#   'Video_Id': 'qjyw8E-kODI',
#   'Comment_Text': 'Super amazing nice continue watching video please next video link',
#   'Comment_Author': '@MANITAMILMOVIES',
#   'Comment_Published': '2024-04-07T20:19:27Z'},
#  {'Comment_Id': 'UgyoOWPOPqUphRy0bjJ4AaABAg',
#   'Video_Id': 'qjyw8E-kODI',
#   'Comment_Text': 'Bro I have one big doubt bro. Iam studied only 12th std without degree. because my family financial situation. But I Very much intrest in IT indestery and learning programming. So can I learn programming after get a IT jobs?',
#   'Comment_Author': '@naveenop4389',
#   'Comment_Published': '2024-03-29T16:44:51Z'},
#  {'Comment_Id': 'UgxQGuJblNNyVnIxfOh4AaABAg',
#   'Video_Id': 'O-XGCubjiwA',
#   'Comment_Text': 'Tally class update pannuga sir please sir please sir reply panuga sir',
#   'Comment_Author': '@SangeethaSangeetha-uu1bd',
#   'Comment_Published': '2024-03-06T03:27:34Z'},
#  {'Comment_Id': 'UgwfgGR4UTZ5k4dnkE94AaABAg',
#   'Video_Id': 'MHhhqiX2HMY',
#   'Comment_Text': 'Tally class update pannuga sir please sir',
#   'Comment_Author': '@SangeethaSangeetha-uu1bd',
#   'Comment_Published': '2024-02-29T10:09:48Z'},
#  {'Comment_Id': 'UgyqjZBp2YU63H8PA_14AaABAg',
#   'Video_Id': 'WolliVBYaCc',
#   'Comment_Text': 'Available branch in madurai',
#   'Comment_Author': '@MUKILKUTTY-wb5xq',
#   'Comment_Published': '2024-01-31T12:44:43Z'},
#  {'Comment_Id': 'UgyUJQQ_8pgPB99SW0x4AaABAg',
#   'Video_Id': 'Vruen6d2d7c',
#   'Comment_Text': 'Very useful sir',
#   'Comment_Author': '@user-ui9ww2ei8b',
#   'Comment_Published': '2024-01-26T10:48:08Z'},
#  {'Comment_Id': 'UgwbeBAA54uOBwEmHXx4AaABAg',
#   'Video_Id': 'LqtxueUmEBw',
#   'Comment_Text': 'Sir',
#   'Comment_Author': '@jawaharjawahar190',
#   'Comment_Published': '2024-01-22T12:15:08Z'},
#  {'Comment_Id': 'UgzGbpLIP-4kpqN6qJl4AaABAg',
#   'Video_Id': 'HrrSB8OWKbA',
#   'Comment_Text': 'Sir eppo post office work poga entha Mari course pannum   i am Redhills so pakathula unaga course center eruka sir',
#   'Comment_Author': '@keerthivengatvengat3711',
#   'Comment_Published': '2024-01-04T08:19:22Z'},
#  {'Comment_Id': 'UgyBhyzp74B2GHBOLKZ4AaABAg',
#   'Video_Id': 'cFQrjXv_Mlk',
#   'Comment_Text': 'Remba Thanks Ayya Vanakkam <br>Madam increase your tone volume excessive Please...<br>Thanks for your Response to Teaching...',
#   'Comment_Author': '@m.duraipandithenmozhi8162',
#   'Comment_Published': '2024-01-02T14:37:41Z'},
#  {'Comment_Id': 'Ugy8W7dGnAnh7pDGjsp4AaABAg',
#   'Video_Id': 'Fxq--YEoiJI',
#   'Comment_Text': 'Vlookup teach pannunga enaku rombo kashtama iruku puriyavae mattenguthu',
#   'Comment_Author': '@gloryiasauskia1688',
#   'Comment_Published': '2023-12-22T19:00:06Z'},
#  {'Comment_Id': 'UgyGF6Hl-t5Au4BRHGV4AaABAg',
#   'Video_Id': 'Fxq--YEoiJI',
#   'Comment_Text': 'Excel online',
#   'Comment_Author': '@almahatraders',
#   'Comment_Published': '2023-12-18T10:15:16Z'},
#  {'Comment_Id': 'UgzdmYow29C9qqE1GxV4AaABAg',
#   'Video_Id': 's5Wb-JAp6zY',
#   'Comment_Text': '👍',
#   'Comment_Author': '@KiriTharan100',
#   'Comment_Published': '2023-12-05T09:57:31Z'},
#  {'Comment_Id': 'Ugzgj0kA7O8uccQ3ydV4AaABAg',
#   'Video_Id': 'fRAZchQnNnI',
#   'Comment_Text': 'Hi sir I want start computer courses  5students ready to come the class.but I want give certificate what can I do give any solution that help for me.',
#   'Comment_Author': '@cpsa.vrundefeatableproduct9823',
#   'Comment_Published': '2023-11-27T14:16:08Z'},
#  {'Comment_Id': 'UgzHZlEGJvmJ_BLvCs14AaABAg',
#   'Video_Id': 'ETnarRAQ2sM',
#   'Comment_Text': 'Sir ஈரோடு ல  class இருக்கா  சார்..',
#   'Comment_Author': '@arivalaganarima6299',
#   'Comment_Published': '2023-11-25T16:32:23Z'},
#  {'Comment_Id': 'UgztAvK--uEDFdkM2vZ4AaABAg',
#   'Video_Id': 'ETnarRAQ2sM',
#   'Comment_Text': 'Sir karur la center iruka pls reply',
#   'Comment_Author': '@abhinavram9594',
#   'Comment_Published': '2023-11-25T03:27:59Z'},
#  {'Comment_Id': 'Ugy50xObCjLe589hBQl4AaABAg',
#   'Video_Id': 'yTZJFIZXdR4',
#   'Comment_Text': 'Thank u mam 🎉',
#   'Comment_Author': '@charleslesner961',
#   'Comment_Published': '2023-11-21T15:04:09Z'},
#  {'Comment_Id': 'UgwVlF9nCPP-8hoCzdZ4AaABAg',
#   'Video_Id': 'yTZJFIZXdR4',
#   'Comment_Text': 'Thank you bro',
#   'Comment_Author': '@sathishkumarsrs5947',
#   'Comment_Published': '2023-11-21T14:54:20Z'},
#  {'Comment_Id': 'UgzPwdNl0V2W7rqazsZ4AaABAg',
#   'Video_Id': 'Ec6jjduAgSg',
#   'Comment_Text': 'Respected sir/madam Vanakkam <br>Thanks sir <br>Fine Explains. Clearly <br>Understandings. 🙏🙏🙏<br>Properly Systematically Teaching Presentation. <br>Excellent Demonstrations. <br>By <br>M.Duraipandi (male)<br>Your Channel subscriber',
#   'Comment_Author': '@m.duraipandithenmozhi8162',
#   'Comment_Published': '2023-11-15T13:19:58Z'},
#  {'Comment_Id': 'UgyDfMR7B51r7sKXxRR4AaABAg',
#   'Video_Id': 'YGzk5xSdyNI',
#   'Comment_Text': 'Sir karur la enga iruku',
#   'Comment_Author': '@abhinavram9594',
#   'Comment_Published': '2023-11-15T02:40:42Z'},
#  {'Comment_Id': 'UgzaO4Q5WGsaGGkAhU94AaABAg',
#   'Video_Id': 'YGzk5xSdyNI',
#   'Comment_Text': '🙏🙏🙏',
#   'Comment_Author': '@m.duraipandithenmozhi8162',
#   'Comment_Published': '2023-11-13T13:07:21Z'},
#  {'Comment_Id': 'UgxUssGF8Wx-r0JI3D14AaABAg',
#   'Video_Id': '5VdHb9nIU_8',
#   'Comment_Text': 'Sir karur la center enga iruku',
#   'Comment_Author': '@abhinavram9594',
#   'Comment_Published': '2023-11-15T02:40:24Z'},
#  {'Comment_Id': 'UgyRkNdp30KeNBwQuOh4AaABAg',
#   'Video_Id': 'hiLrxd2llP8',
#   'Comment_Text': 'Sir karur la enga iruku',
#   'Comment_Author': '@abhinavram9594',
#   'Comment_Published': '2023-11-14T15:34:12Z'},
#  {'Comment_Id': 'Ugz3AEXNg1iaBsr6CQB4AaABAg',
#   'Video_Id': 'ik49Q87-UVg',
#   'Comment_Text': 'Thank you Madam.',
#   'Comment_Author': '@englishforre.1458',
#   'Comment_Published': '2023-12-05T02:53:42Z'},
#  {'Comment_Id': 'UgxfzhR8UpsP33bl70d4AaABAg',
#   'Video_Id': 'BQoAShHkCxg',
#   'Comment_Text': 'Basic a computer teriyathu mam enaku... Ipo nenga solli tharathu rompa use ful aa eruku mam... Thank u mam... Regulara video potunga mam👍',
#   'Comment_Author': '@arockiyaninisha6381',
#   'Comment_Published': '2023-12-15T05:50:46Z'},
#  {'Comment_Id': 'UgyXfostIOZ8Qji-KwV4AaABAg',
#   'Video_Id': 'Cz9zEVBPLbc',
#   'Comment_Text': '🙏🙏🙏👏👏👏✍✍✍💥💥💥👍👍👍',
#   'Comment_Author': '@m.duraipandithenmozhi8162',
#   'Comment_Published': '2023-10-30T12:38:12Z'},
#  {'Comment_Id': 'Ugzkw7KSo3t1G4bcIlR4AaABAg',
#   'Video_Id': 'Uigbl3eGvkg',
#   'Comment_Text': 'Intha centre government conducte panarangala illa private center ah sir',
#   'Comment_Author': '@KARTHICKM-pn5rl',
#   'Comment_Published': '2023-12-30T05:54:18Z'},
#  {'Comment_Id': 'Ugz0noftOBhBXDeq32N4AaABAg',
#   'Video_Id': 'Uigbl3eGvkg',
#   'Comment_Text': 'Mam video send me',
#   'Comment_Author': '@SangeethaSangeetha-uu1bd',
#   'Comment_Published': '2023-10-28T12:57:25Z'},
#  {'Comment_Id': 'UgzuUhLQgTUD3QJXYAd4AaABAg',
#   'Video_Id': 'Uigbl3eGvkg',
#   'Comment_Text': 'Excellent   Explains .Thanks Madam Vanakkam',
#   'Comment_Author': '@m.duraipandithenmozhi8162',
#   'Comment_Published': '2023-10-27T13:43:53Z'},
#  {'Comment_Id': 'Ugzc6KGqFZuoxrp3kxh4AaABAg',
#   'Video_Id': 'Uigbl3eGvkg',
#   'Comment_Text': 'Welcome sir/Madam.Thanks. <br>M.Duraipandi Senior Citizen',
#   'Comment_Author': '@m.duraipandithenmozhi8162',
#   'Comment_Published': '2023-10-27T13:12:37Z'},
#  {'Comment_Id': 'UgxX4icbfQ7SZdHgehN4AaABAg',
#   'Video_Id': 'z8yrhUZqae8',
#   'Comment_Text': 'Revised learning. Thanks',
#   'Comment_Author': '@m.duraipandithenmozhi8162',
#   'Comment_Published': '2023-12-13T10:44:45Z'},
#  {'Comment_Id': 'UgwxQCTcii4cC4bABtV4AaABAg',
#   'Video_Id': 'z8yrhUZqae8',
#   'Comment_Text': 'Respected sir Vanakkam <br>Respected Madam Thanks.',
#   'Comment_Author': '@m.duraipandithenmozhi8162',
#   'Comment_Published': '2023-10-23T12:38:01Z'},
#  {'Comment_Id': 'UgxqdDyzJLesnwxnNt14AaABAg',
#   'Video_Id': 'QyWDePmODE8',
#   'Comment_Text': 'Ms word step writing pdf please mam',
#   'Comment_Author': '@SangeethaSangeetha-uu1bd',
#   'Comment_Published': '2023-10-21T15:49:06Z'},
#  {'Comment_Id': 'UgxC1bZ2YKkWzeBbtgZ4AaABAg',
#   'Video_Id': 'QyWDePmODE8',
#   'Comment_Text': 'Respected <br>TCDS Sir,Vanakkam <br>Respected Madam Vanakkam. <br>Your Teaching is FINE...THANKS. <br>I am Elder .Good Understandings <br>Your Teaching. Full lesson video watching and and  learnt the Study Materials. Once again Thanks sir...<br>By M.Duraipandi Senior Citizen your Channel subscriber',
#   'Comment_Author': '@m.duraipandithenmozhi8162',
#   'Comment_Published': '2023-10-20T14:32:07Z'},
#  {'Comment_Id': 'UgxYHD9aWqR_V_9Sccd4AaABAg',
#   'Video_Id': 'QyWDePmODE8',
#   'Comment_Text': 'Very Good Welcome sir/Madam. <br>Thanks for your Presentations. 🙏🙏🙏👏👏👏💥💥💥💥✍✍✍<br>By M.Duraipandi Senior Citizen your Channel subscriber.',
#   'Comment_Author': '@m.duraipandithenmozhi8162',
#   'Comment_Published': '2023-10-20T14:04:00Z'},
#  {'Comment_Id': 'UgzA4xpMaQ-uJzNY7zx4AaABAg',
#   'Video_Id': 'C9QnF2JWVIs',
#   'Comment_Text': 'Best teaching thank you medam🎉❤',
#   'Comment_Author': '@gokuln5415',
#   'Comment_Published': '2023-10-19T12:44:46Z'},
#  {'Comment_Id': 'Ugy8gTHUxjjwA47FvnB4AaABAg',
#   'Video_Id': 'C9QnF2JWVIs',
#   'Comment_Text': 'Trichy la center enga irrukku',
#   'Comment_Author': '@PearlzAaricreatives',
#   'Comment_Published': '2023-10-19T10:22:36Z'},
#  {'Comment_Id': 'Ugxev_8UvZEpJ_VSSmV4AaABAg',
#   'Video_Id': 'C9QnF2JWVIs',
#   'Comment_Text': 'Welcome Sir/Madam <br>Vanakkam Thanks',
#   'Comment_Author': '@m.duraipandithenmozhi8162',
#   'Comment_Published': '2023-10-18T13:33:18Z'},
#  {'Comment_Id': 'Ugw22Po8WrGqWuHXXLl4AaABAg',
#   'Video_Id': '_4JAb86GhjM',
#   'Comment_Text': '🙏🙏🙏👍👍👍👏👏👏💥💥💥✍✍✍',
#   'Comment_Author': '@m.duraipandithenmozhi8162',
#   'Comment_Published': '2023-10-16T13:28:55Z'},
#  {'Comment_Id': 'UgxV1DUk7PKDe-V5xH94AaABAg',
#   'Video_Id': 'H0T3vBUUIvA',
#   'Comment_Text': 'Thanks sir Vanakkam Madam',
#   'Comment_Author': '@m.duraipandithenmozhi8162',
#   'Comment_Published': '2023-10-12T14:55:29Z'},
#  {'Comment_Id': 'UgxOqmvx0glPfIpNqS54AaABAg',
#   'Video_Id': 'H0T3vBUUIvA',
#   'Comment_Text': 'Vanakkam sir❤',
#   'Comment_Author': '@rajendranrajendranrr3996',
#   'Comment_Published': '2023-10-11T12:30:56Z'},
#  {'Comment_Id': 'UgyJIOi1eXidsHIkEKJ4AaABAg',
#   'Video_Id': 'TdMfIBD00hA',
#   'Comment_Text': 'Respected sir/madam Vanakkam Thanks',
#   'Comment_Author': '@m.duraipandithenmozhi8162',
#   'Comment_Published': '2023-12-12T13:02:25Z'},
#  {'Comment_Id': 'UgxOxPP0j_7EBkKdPaJ4AaABAg',
#   'Video_Id': 'TdMfIBD00hA',
#   'Comment_Text': 'Welcome sir Vanakkam <br>Thanks Madam Vanakkam<br>By<br>M.Duraipandi Senior Citizen <br>Your Channel subscriber',
#   'Comment_Author': '@m.duraipandithenmozhi8162',
#   'Comment_Published': '2023-10-06T13:54:01Z'},
#  {'Comment_Id': 'UgwfMcJ-Dhxu7HJEf9J4AaABAg',
#   'Video_Id': 'NmqvmWK5LDA',
#   'Comment_Text': 'Free ya sir course',
#   'Comment_Author': '@SomiyaSowmi-ks1dk',
#   'Comment_Published': '2023-10-14T14:55:59Z'},
#  {'Comment_Id': 'Ugztadtc7hHEciU7myh4AaABAg',
#   'Video_Id': 'NmqvmWK5LDA',
#   'Comment_Text': '👏👍🙏🎉',
#   'Comment_Author': '@SP-on2dw',
#   'Comment_Published': '2023-10-05T09:27:09Z'},
#  {'Comment_Id': 'UgxxY0f_Ed-sOXrUy5F4AaABAg',
#   'Video_Id': 'NmqvmWK5LDA',
#   'Comment_Text': 'Nalla Explains<br>Madam/Sir Vanakkam',
#   'Comment_Author': '@m.duraipandithenmozhi8162',
#   'Comment_Published': '2023-10-04T13:31:30Z'},
#  {'Comment_Id': 'UgzTZ-jYLk4orOT38Wd4AaABAg',
#   'Video_Id': 'NmqvmWK5LDA',
#   'Comment_Text': 'Thanks Madam/Sir Vanakkam. <br>I watch this Lesson',
#   'Comment_Author': '@m.duraipandithenmozhi8162',
#   'Comment_Published': '2023-10-04T13:06:04Z'},
#  {'Comment_Id': 'UgxepYzua1fMEW--G6B4AaABAg',
#   'Video_Id': 'D7V3FMiqAmU',
#   'Comment_Text': 'Excellently Presented',
#   'Comment_Author': '@anbannagayam1558',
#   'Comment_Published': '2024-04-05T14:43:16Z'},
#  {'Comment_Id': 'Ugyb60EKlk5_wRr4PS14AaABAg',
#   'Video_Id': 'JAvO-7Pj2X8',
#   'Comment_Text': 'Promo&gt;SM 😝',
#   'Comment_Author': '@dwighte5482',
#   'Comment_Published': '2023-10-18T00:41:35Z'},
#  {'Comment_Id': 'Ugz5s3u4fEYN_R_-gpp4AaABAg',
#   'Video_Id': 'JAvO-7Pj2X8',
#   'Comment_Text': 'Computer course online la iruka fees yevalavu',
#   'Comment_Author': '@Denudp-vs1fl',
#   'Comment_Published': '2023-09-29T16:27:03Z'},
#  {'Comment_Id': 'UgwW4pf7Gypml-BjQX94AaABAg',
#   'Video_Id': 'HX44Dh1LCRs',
#   'Comment_Text': 'Respected sir/madam,<br>Thanks for your Presentations.',
#   'Comment_Author': '@m.duraipandithenmozhi8162',
#   'Comment_Published': '2023-10-17T12:05:45Z'},
#  {'Comment_Id': 'UgwCJHyT7b_1MgbzJlR4AaABAg',
#   'Video_Id': 'QWjLg87QomM',
#   'Comment_Text': 'Excellent Presentation.',
#   'Comment_Author': '@anbannagayam1558',
#   'Comment_Published': '2024-03-01T19:47:45Z'},
#  {'Comment_Id': 'UgyoGfYQ5t9t_2-nRIR4AaABAg',
#   'Video_Id': 'QWjLg87QomM',
#   'Comment_Text': 'Nantry sir💐💐💐',
#   'Comment_Author': '@rajendranrajendranrr3996',
#   'Comment_Published': '2023-09-20T12:31:54Z'},
#  {'Comment_Id': 'UgxCC8yQPvaXV6y5XC94AaABAg',
#   'Video_Id': 'QWjLg87QomM',
#   'Comment_Text': '🎉🎉🎉🎉',
#   'Comment_Author': '@rajendranrajendranrr3996',
#   'Comment_Published': '2023-09-20T12:31:28Z'},
#  {'Comment_Id': 'Ugy6e-b3M6FVQ0j3Nyp4AaABAg',
#   'Video_Id': '5LF0SlTWKfU',
#   'Comment_Text': 'Nalla Explains sir/Madam Vanakkam. Thanks',
#   'Comment_Author': '@m.duraipandithenmozhi8162',
#   'Comment_Published': '2023-10-17T11:48:50Z'},
#  {'Comment_Id': 'UgxDMkD5cEoZDj75f0h4AaABAg',
#   'Video_Id': '5LF0SlTWKfU',
#   'Comment_Text': 'எங்க இருக்கு',
#   'Comment_Author': '@sammugapriyasriram7157',
#   'Comment_Published': '2023-09-09T12:48:48Z'},
#  {'Comment_Id': 'Ugz_QfH5lsDo2Vzdu0N4AaABAg',
#   'Video_Id': 'qyO35ZTAeIc',
#   'Comment_Text': 'Very useful thank u',
#   'Comment_Author': '@Mah-vc8ni',
#   'Comment_Published': '2023-08-27T07:44:54Z'},
#  {'Comment_Id': 'Ugzgihe5kv37p_oQ1td4AaABAg',
#   'Video_Id': 'TPPAsipuwdI',
#   'Comment_Text': 'My place vellore',
#   'Comment_Author': '@arul10114',
#   'Comment_Published': '2024-04-25T10:27:35Z'},
#  {'Comment_Id': 'Ugxn4A-Dg8g4M4klkVB4AaABAg',
#   'Video_Id': 'TPPAsipuwdI',
#   'Comment_Text': 'Basic computer using solli thannga madam',
#   'Comment_Author': '@ArunKumar-wc3ec',
#   'Comment_Published': '2023-08-24T14:57:26Z'},
#  {'Comment_Id': 'Ugz5SL6xPkMWmBi3yRd4AaABAg',
#   'Video_Id': 'LJCnwWln_0Q',
#   'Comment_Text': 'Thank you Madam.',
#   'Comment_Author': '@englishforre.1458',
#   'Comment_Published': '2023-12-09T12:00:16Z'},
#  {'Comment_Id': 'Ugwo0v_nqjL2BAazMU14AaABAg',
#   'Video_Id': 'M1G5t0drYQU',
#   'Comment_Text': 'Thank you Madam.',
#   'Comment_Author': '@englishforre.1458',
#   'Comment_Published': '2023-12-09T11:37:34Z'},
#  {'Comment_Id': 'Ugzx9VUV_hR7tdk_8aR4AaABAg',
#   'Video_Id': 'M1G5t0drYQU',
#   'Comment_Text': 'Very useful video',
#   'Comment_Author': '@sandhiyabalu309',
#   'Comment_Published': '2023-08-18T06:50:25Z'},
#  {'Comment_Id': 'UgznFoNU2H8T0Jn_Gjt4AaABAg',
#   'Video_Id': 'vq6u1m-v9dY',
#   'Comment_Text': 'Thank u,clear teaching',
#   'Comment_Author': '@nagarathinamgulothungan8828',
#   'Comment_Published': '2024-03-10T16:07:31Z'},
#  {'Comment_Id': 'UgzJPGhsh4GJmHpMfzJ4AaABAg',
#   'Video_Id': 'vq6u1m-v9dY',
#   'Comment_Text': 'Thank you Madam . Your teaching is very clear and could be understood easily.',
#   'Comment_Author': '@englishforre.1458',
#   'Comment_Published': '2023-12-05T16:31:29Z'},
#  {'Comment_Id': 'UgybZR7tvkq9-IYGAjJ4AaABAg',
#   'Video_Id': '1i-mYQRFBBo',
#   'Comment_Text': 'Very useful for all thank u🎉',
#   'Comment_Author': '@Mah-vc8ni',
#   'Comment_Published': '2023-08-26T10:55:54Z'},
#  {'Comment_Id': 'Ugx8NaC4E3yPxBWGLHl4AaABAg',
#   'Video_Id': 'X3OmRQGXK4k',
#   'Comment_Text': 'Thanks Madam Vanakkam',
#   'Comment_Author': '@m.duraipandithenmozhi8162',
#   'Comment_Published': '2024-05-13T14:21:34Z'},
#  {'Comment_Id': 'UgxSosVFhbk4fSdXq8R4AaABAg',
#   'Video_Id': 'X3OmRQGXK4k',
#   'Comment_Text': 'Redhillsla yanga irukku sir',
#   'Comment_Author': '@anitham8924',
#   'Comment_Published': '2024-04-25T12:17:42Z'},
#  {'Comment_Id': 'Ugyt2hmYd0f6QLIKpVt4AaABAg',
#   'Video_Id': 'X3OmRQGXK4k',
#   'Comment_Text': '❤❤❤❤',
#   'Comment_Author': '@lokerkey5339',
#   'Comment_Published': '2024-04-23T09:24:38Z'},
#  {'Comment_Id': 'Ugzti0Il8z4i2b5Hnzt4AaABAg',
#   'Video_Id': 'X3OmRQGXK4k',
#   'Comment_Text': 'Very useful',
#   'Comment_Author': '@lokerkey5339',
#   'Comment_Published': '2024-04-23T09:24:28Z'},
#  {'Comment_Id': 'UgzKrPhflNSpql4m8ld4AaABAg',
#   'Video_Id': 'X3OmRQGXK4k',
#   'Comment_Text': 'Thank you mam',
#   'Comment_Author': '@lokerkey5339',
#   'Comment_Published': '2024-04-23T09:24:15Z'},
#  {'Comment_Id': 'UgzKcjctuiuCTyAELll4AaABAg',
#   'Video_Id': 'X3OmRQGXK4k',
#   'Comment_Text': 'Nice explanation',
#   'Comment_Author': '@user-xq1dc5mx3e',
#   'Comment_Published': '2024-03-26T15:08:17Z'},
#  {'Comment_Id': 'UgwTmuKC6mRTYl4z-9x4AaABAg',
#   'Video_Id': 'X3OmRQGXK4k',
#   'Comment_Text': 'Computer course and ICT course same aahh?',
#   'Comment_Author': '@anukambikaivani435',
#   'Comment_Published': '2024-03-05T04:35:53Z'},
#  {'Comment_Id': 'UgwmdhGKA2yEg6A_GT54AaABAg',
#   'Video_Id': 'X3OmRQGXK4k',
#   'Comment_Text': 'Computer cilass yenga irukku',
#   'Comment_Author': '@rathishrathish9191',
#   'Comment_Published': '2024-02-16T12:47:53Z'},
#  {'Comment_Id': 'Ugzir6cgikuWm89BUYx4AaABAg',
#   'Video_Id': 'X3OmRQGXK4k',
#   'Comment_Text': 'Thank you mam',
#   'Comment_Author': '@user-ih1nu3jk7k',
#   'Comment_Published': '2024-02-06T16:48:14Z'},
#  {'Comment_Id': 'UgzKANJ8IggbD-p6CZt4AaABAg',
#   'Video_Id': 'X3OmRQGXK4k',
#   'Comment_Text': 'Kanchipuram la office irrruka',
#   'Comment_Author': '@praveenkumarkkms7756',
#   'Comment_Published': '2024-01-26T02:13:56Z'},
#  {'Comment_Id': 'UgyijH3XzJmzbyBc_rp4AaABAg',
#   'Video_Id': 'X3OmRQGXK4k',
#   'Comment_Text': 'Mam computer basic yethuvum theryala but  now I&#39;m going to offline course so guide me plz',
#   'Comment_Author': '@dephiyagomas8047',
#   'Comment_Published': '2024-01-12T11:05:25Z'},
#  {'Comment_Id': 'Ugx20EI7OFjsmuuHjtt4AaABAg',
#   'Video_Id': 'X3OmRQGXK4k',
#   'Comment_Text': 'This information is super helpful and easy to understand, especially for those who are just starting! for beginners.',
#   'Comment_Author': '@thennarasu1592',
#   'Comment_Published': '2023-12-30T11:57:39Z'},
#  {'Comment_Id': 'UgxePehV6LogVmRpJZJ4AaABAg',
#   'Video_Id': 'X3OmRQGXK4k',
#   'Comment_Text': 'Very useful  👌',
#   'Comment_Author': '@banupriya2507',
#   'Comment_Published': '2023-12-22T16:46:33Z'},
#  {'Comment_Id': 'Ugy_ITk5C4MAmVpU2E14AaABAg',
#   'Video_Id': 'X3OmRQGXK4k',
#   'Comment_Text': 'Address send me mam',
#   'Comment_Author': '@POORNIMAPOORNIMA-ib3lj',
#   'Comment_Published': '2023-12-21T13:37:32Z'},
#  {'Comment_Id': 'UgzkiCEFwaPStGjOATJ4AaABAg',
#   'Video_Id': 'X3OmRQGXK4k',
#   'Comment_Text': 'Good, How many bees',
#   'Comment_Author': '@natarajansn8728',
#   'Comment_Published': '2023-12-20T13:26:08Z'},
#  {'Comment_Id': 'UgxQ-1nDRps8j7KVeaF4AaABAg',
#   'Video_Id': 'X3OmRQGXK4k',
#   'Comment_Text': 'Very useful',
#   'Comment_Author': '@kuttypranav1311',
#   'Comment_Published': '2023-12-14T04:14:25Z'},
#  {'Comment_Id': 'UgyFmWsy6l8BvC1kMdR4AaABAg',
#   'Video_Id': 'X3OmRQGXK4k',
#   'Comment_Text': 'How to get certificate',
#   'Comment_Author': '@keerthanakeerthi3489',
#   'Comment_Published': '2023-12-13T17:00:03Z'},
#  {'Comment_Id': 'UgyasxgXtT2CrUvlKkR4AaABAg',
#   'Video_Id': 'X3OmRQGXK4k',
#   'Comment_Text': 'Thank you Madam . Please teach me more.',
#   'Comment_Author': '@englishforre.1458',
#   'Comment_Published': '2023-12-02T08:58:03Z'},
#  {'Comment_Id': 'Ugw1pLuezEmLRKXTp614AaABAg',
#   'Video_Id': 'X3OmRQGXK4k',
#   'Comment_Text': 'Good experience and explain',
#   'Comment_Author': '@rameshkumari8943',
#   'Comment_Published': '2023-11-28T05:49:52Z'},
#  {'Comment_Id': 'UgyOK76wU7kwM6-19ud4AaABAg',
#   'Video_Id': 'X3OmRQGXK4k',
#   'Comment_Text': 'Thank you madam it&#39;s very useful again and again thank you very much',
#   'Comment_Author': '@rameshkumari8943',
#   'Comment_Published': '2023-11-28T05:48:57Z'},
#  {'Comment_Id': 'UgyxTVkel8k7dw8cduV4AaABAg',
#   'Video_Id': 'X3OmRQGXK4k',
#   'Comment_Text': 'Super mam',
#   'Comment_Author': '@ravindranmsc2986',
#   'Comment_Published': '2023-11-19T08:04:27Z'},
#  {'Comment_Id': 'UgxYxgTAefcgKpJNxrJ4AaABAg',
#   'Video_Id': 'X3OmRQGXK4k',
#   'Comment_Text': 'Computer course learn pannanum help pannuinga',
#   'Comment_Author': '@mohanrajs1568',
#   'Comment_Published': '2023-08-13T08:20:08Z'},
#  {'Comment_Id': 'UgyAjIXDv0W9D4WeIPN4AaABAg',
#   'Video_Id': 'BqnDI6nKKo0',
#   'Comment_Text': 'Enaku TCDS computer certificate iruku anda scholarship eppati use panradu enka poi Scholarship ku Register pannanum sonnunka please',
#   'Comment_Author': '@muruganaachri7840',
#   'Comment_Published': '2024-01-22T13:10:27Z'},
#  {'Comment_Id': 'Ugxr9lSWkYQsUhIPZEV4AaABAg',
#   'Video_Id': 'BqnDI6nKKo0',
#   'Comment_Text': 'Details sollunga sir',
#   'Comment_Author': '@dangerqueen9773',
#   'Comment_Published': '2023-12-13T01:45:34Z'},
#  {'Comment_Id': 'UgyuqU0LYbbTm37lLwh4AaABAg',
#   'Video_Id': 'LWvMOC8rw_M',
#   'Comment_Text': 'tq mam',
#   'Comment_Author': '@aishwaryaraja9757',
#   'Comment_Published': '2023-07-07T19:03:40Z'},
#  {'Comment_Id': 'Ugy34DONDzrkqIGZBCt4AaABAg',
#   'Video_Id': 'YflWA5oZeug',
#   'Comment_Text': 'Great job mam,  inspired with your way of teaching',
#   'Comment_Author': '@user-ki7rg9jb2w',
#   'Comment_Published': '2023-07-03T14:23:08Z'},
#  {'Comment_Id': 'UgyF20mF1fuwLp0CgjR4AaABAg',
#   'Video_Id': 'YflWA5oZeug',
#   'Comment_Text': 'Informative video 👍',
#   'Comment_Author': '@siddhivinayaka7256',
#   'Comment_Published': '2023-07-03T14:00:46Z'},
#  {'Comment_Id': 'UgyMQmQpDDTdFYE9KGt4AaABAg',
#   'Video_Id': 'e8Kmpz1xGnY',
#   'Comment_Text': 'Eppadi intha course join pannanum',
#   'Comment_Author': '@suryathirumoorthisuryathir8540',
#   'Comment_Published': '2023-04-16T13:51:05Z'},
#  {'Comment_Id': 'UgwNQWNLoQ8705Er6U14AaABAg',
#   'Video_Id': 'kp7guPJ7FMU',
#   'Comment_Text': 'Thank you mam',
#   'Comment_Author': '@inbarasuv1565',
#   'Comment_Published': '2023-04-10T08:23:48Z'},
#  {'Comment_Id': 'UgxxlwF2msc3hvUYOfB4AaABAg',
#   'Video_Id': '0xp9nMLf61Y',
#   'Comment_Text': 'God Blessings you &amp;your family and your team mates.',
#   'Comment_Author': '@m.duraipandithenmozhi8162',
#   'Comment_Published': '2023-10-13T07:09:16Z'},
#  {'Comment_Id': 'UgybEhsZJVvk-ygtCEJ4AaABAg',
#   'Video_Id': '0xp9nMLf61Y',
#   'Comment_Text': 'Really Your Teaching lessons are Very Important .',
#   'Comment_Author': '@m.duraipandithenmozhi8162',
#   'Comment_Published': '2023-10-13T06:54:06Z'},
#  {'Comment_Id': 'UgykHyEqt1Fc7xzjwNR4AaABAg',
#   'Video_Id': 'Se9eTmuAdME',
#   'Comment_Text': 'Very good teaching',
#   'Comment_Author': '@elanexplore8564',
#   'Comment_Published': '2023-04-01T00:19:37Z'},
#  {'Comment_Id': 'Ugwpaec-dVAurs_VScR4AaABAg',
#   'Video_Id': 'Se9eTmuAdME',
#   'Comment_Text': 'Thanks for your information',
#   'Comment_Author': '@TCDS2021-le4gi',
#   'Comment_Published': '2023-03-31T16:53:44Z'},
#  {'Comment_Id': 'UgyessA46P5VS__xysh4AaABAg',
#   'Video_Id': 'Se9eTmuAdME',
#   'Comment_Text': '👍👍👍👏👏👏🙏🙏🙏',
#   'Comment_Author': '@SP-on2dw',
#   'Comment_Published': '2023-03-31T16:39:43Z'},
#  {'Comment_Id': 'UgylJBWFTKBFzgVEPXB4AaABAg',
#   'Video_Id': 'LbzbDLnEDF8',
#   'Comment_Text': '78.9 SC femalekku kidaikkuma',
#   'Comment_Author': '@MuthuMuthu-kv4ix',
#   'Comment_Published': '2022-07-03T09:24:51Z'},
#  {'Comment_Id': 'UgyJfLW0GuqwMh09ach4AaABAg',
#   'Video_Id': 'M7DjoEJ78Ic',
#   'Comment_Text': 'Tell the important points',
#   'Comment_Author': '@ManjushaManju-dp6nh',
#   'Comment_Published': '2024-04-13T06:04:52Z'},
#  {'Comment_Id': 'UgyciurQtTqBj0xjFRh4AaABAg',
#   'Video_Id': 'M7DjoEJ78Ic',
#   'Comment_Text': 'Sir how to run project center then how to give certificate',
#   'Comment_Author': '@SudhandhiraDhanaraj',
#   'Comment_Published': '2024-03-13T02:08:19Z'},
#  {'Comment_Id': 'UgwdGWW8s_jan64spPt4AaABAg',
#   'Video_Id': 'M7DjoEJ78Ic',
#   'Comment_Text': 'Hi',
#   'Comment_Author': '@thirumalai3459',
#   'Comment_Published': '2022-01-23T16:45:20Z'},
#  {'Comment_Id': 'UgwnNeuJpFKYtD_h4yR4AaABAg',
#   'Video_Id': 'ihVMY7FHebM',
#   'Comment_Text': '😊',
#   'Comment_Author': '@ramachandiranp4809',
#   'Comment_Published': '2024-03-28T09:57:18Z'},
#  {'Comment_Id': 'UgyA53u-WscV6GJ7i094AaABAg',
#   'Video_Id': '42JvaVtNGpE',
#   'Comment_Text': 'Antha 2 course enanu.solavae ila. Pls tell about 2 courses.',
#   'Comment_Author': '@petcute2572',
#   'Comment_Published': '2022-06-06T06:10:00Z'},
#  {'Comment_Id': 'Ugzvs_sLfSOhvgCqzzl4AaABAg',
#   'Video_Id': '42JvaVtNGpE',
#   'Comment_Text': 'உங்களுடைய தொலைபேசி எண்?',
#   'Comment_Author': '@hivenkihru27',
#   'Comment_Published': '2022-05-03T14:41:03Z'},
#  {'Comment_Id': 'UgxiCXkaj8WcNjBHBJB4AaABAg',
#   'Video_Id': '0gVsNO1Gusg',
#   'Comment_Text': 'Super',
#   'Comment_Author': '@csricomputereducation1394',
#   'Comment_Published': '2020-03-28T05:28:34Z'}]

# %%
# get_playlist_details

def get_playlist_details(channel_id):

        next_page_token = None

        All_data = []

        while True:

                request = youtube.playlists().list(
                        part = 'snippet,contentDetails',
                        channelId = channel_id,
                        maxResults = 50,
                        pageToken = next_page_token)

                response = request.execute()

                for item in response ['items']:
                        data = dict (Playlist_Id = item['id'],
                                        Title = item ['snippet']['title'],
                                        Channel_Id = item['snippet']['channelId'],
                                        Channel_Name = item['snippet']['channelTitle'],
                                        PublishedAt = item['snippet']['publishedAt'],
                                        Video_Count = item['contentDetails']['itemCount'])
                        All_data.append(data)
                
                next_page_token = response.get('nextPageToken')

                if next_page_token is None:
                        break

        return All_data

# %%
playlist_details = get_playlist_details('UCVRi4KY1YQ6kNkKgR-pvk0A')

# %%
len(playlist_details)
# Out:
# 19

# %%
playlist_details
# Out:
# [{'Playlist_Id': 'PLidfJaBTFqttk1GAnOR4mR4D_xx-i8PkV',
#   'Title': '18. MS POWER POINT [ LAB ]',
#   'Channel_Id': 'UCVRi4KY1YQ6kNkKgR-pvk0A',
#   'Channel_Name': 'TCDS COMPUTER EDUCATION',
#   'PublishedAt': '2024-04-11T12:33:23Z',
#   'Video_Count': 5},
#  {'Playlist_Id': 'PLidfJaBTFqtuHILw2rLTtCfNw2gHnJWSt',
#   'Title': '18. MS POWERPOINT',
#   'Channel_Id': 'UCVRi4KY1YQ6kNkKgR-pvk0A',
#   'Channel_Name': 'TCDS COMPUTER EDUCATION',
#   'PublishedAt': '2024-04-11T12:32:57Z',
#   'Video_Count': 0},
#  {'Playlist_Id': 'PLidfJaBTFqtuJSIxBrykC0qUaGc7O8f1r',
#   'Title': '17. MS POWERPOINT [ CLASS ]',
#   'Channel_Id': 'UCVRi4KY1YQ6kNkKgR-pvk0A',
#   'Channel_Name': 'TCDS COMPUTER EDUCATION',
#   'PublishedAt': '2024-04-05T04:56:40Z',
#   'Video_Count': 6},
#  {'Playlist_Id': 'PLidfJaBTFqtvjyw8J_AUgbipFJJBJ9Fla',
#   'Title': '16. PYTHON [ LAB ]',
#   'Channel_Id': 'UCVRi4KY1YQ6kNkKgR-pvk0A',
#   'Channel_Name': 'TCDS COMPUTER EDUCATION',
#   'PublishedAt': '2024-02-16T04:26:30Z',
#   'Video_Count': 9},
#  {'Playlist_Id': 'PLidfJaBTFqttTkvzDbz80Ozsu0EMH83ff',
#   'Title': '15. PYTHON [ CLASS ]',
#   'Channel_Id': 'UCVRi4KY1YQ6kNkKgR-pvk0A',
#   'Channel_Name': 'TCDS COMPUTER EDUCATION',
#   'PublishedAt': '2024-02-02T12:27:02Z',
#   'Video_Count': 16},
#  {'Playlist_Id': 'PLidfJaBTFqtvnGGWub5qFKJHt6sRAyo32',
#   'Title': '14. INTERNET [ LAB ]',
#   'Channel_Id': 'UCVRi4KY1YQ6kNkKgR-pvk0A',
#   'Channel_Name': 'TCDS COMPUTER EDUCATION',
#   'PublishedAt': '2023-12-29T07:59:15Z',
#   'Video_Count': 1},
#  {'Playlist_Id': 'PLidfJaBTFqtsQfhVfzNkD7LiZ4c_QJBSY',
#   'Title': '13. INTERNET[CLASS]',
#   'Channel_Id': 'UCVRi4KY1YQ6kNkKgR-pvk0A',
#   'Channel_Name': 'TCDS COMPUTER EDUCATION',
#   'PublishedAt': '2023-12-20T04:19:33Z',
#   'Video_Count': 5},
#  {'Playlist_Id': 'PLidfJaBTFqtuu7TikwQt_VABbPNgHCL4L',
#   'Title': '12. WINDOWS [ LAB ]',
#   'Channel_Id': 'UCVRi4KY1YQ6kNkKgR-pvk0A',
#   'Channel_Name': 'TCDS COMPUTER EDUCATION',
#   'PublishedAt': '2023-11-03T10:05:24Z',
#   'Video_Count': 4},
#  {'Playlist_Id': 'PLidfJaBTFqtu8L7PT2uc4_c2BqWUEp7sE',
#   'Title': '11. WINDOWS [CLASS]',
#   'Channel_Id': 'UCVRi4KY1YQ6kNkKgR-pvk0A',
#   'Channel_Name': 'TCDS COMPUTER EDUCATION',
#   'PublishedAt': '2023-11-03T09:59:21Z',
#   'Video_Count': 12},
#  {'Playlist_Id': 'PLidfJaBTFqtsrwuJjAHTD1bzy3V9qHUP_',
#   'Title': '10. MS EXCEL [ LAB ]',
#   'Channel_Id': 'UCVRi4KY1YQ6kNkKgR-pvk0A',
#   'Channel_Name': 'TCDS COMPUTER EDUCATION',
#   'PublishedAt': '2023-11-01T09:14:02Z',
#   'Video_Count': 18},
#  {'Playlist_Id': 'PLidfJaBTFqttRVpWQJHEyulaP8Eg6nEIk',
#   'Title': '9. MS EXCEL [ CLASS ]',
#   'Channel_Id': 'UCVRi4KY1YQ6kNkKgR-pvk0A',
#   'Channel_Name': 'TCDS COMPUTER EDUCATION',
#   'PublishedAt': '2023-10-27T04:32:21Z',
#   'Video_Count': 20},
#  {'Playlist_Id': 'PLidfJaBTFqtuibseNImCQ5GOJeq-ujqj9',
#   'Title': '8. GENERAL',
#   'Channel_Id': 'UCVRi4KY1YQ6kNkKgR-pvk0A',
#   'Channel_Name': 'TCDS COMPUTER EDUCATION',
#   'PublishedAt': '2023-08-18T05:35:33Z',
#   'Video_Count': 7},
#  {'Playlist_Id': 'PLidfJaBTFqtutY_TWR3Srm4bcHezkMQ6e',
#   'Title': '5. FUNDAMENTALS [ LAB]',
#   'Channel_Id': 'UCVRi4KY1YQ6kNkKgR-pvk0A',
#   'Channel_Name': 'TCDS COMPUTER EDUCATION',
#   'PublishedAt': '2023-08-12T10:46:47Z',
#   'Video_Count': 2},
#  {'Playlist_Id': 'PLidfJaBTFqtuKnQZg3N2mXwCNwLezw0Uy',
#   'Title': '4. FUNDAMENTALS [ CLASS ]',
#   'Channel_Id': 'UCVRi4KY1YQ6kNkKgR-pvk0A',
#   'Channel_Name': 'TCDS COMPUTER EDUCATION',
#   'PublishedAt': '2023-07-03T11:07:12Z',
#   'Video_Count': 7},
#  {'Playlist_Id': 'PLidfJaBTFqtsUCJwbzynATIUQsclYCld1',
#   'Title': '3. ADVERTISEMENTS',
#   'Channel_Id': 'UCVRi4KY1YQ6kNkKgR-pvk0A',
#   'Channel_Name': 'TCDS COMPUTER EDUCATION',
#   'PublishedAt': '2023-04-30T06:29:17Z',
#   'Video_Count': 1},
#  {'Playlist_Id': 'PLidfJaBTFqtsV_z5bMb5f_HdsLkcjBG3R',
#   'Title': '7. MS WORD [ LAB ]',
#   'Channel_Id': 'UCVRi4KY1YQ6kNkKgR-pvk0A',
#   'Channel_Name': 'TCDS COMPUTER EDUCATION',
#   'PublishedAt': '2023-04-04T11:44:49Z',
#   'Video_Count': 10},
#  {'Playlist_Id': 'PLidfJaBTFqtskjMcGZFfCfk4GQeN7dmf5',
#   'Title': '6. MS WORD [ CLASS ]',
#   'Channel_Id': 'UCVRi4KY1YQ6kNkKgR-pvk0A',
#   'Channel_Name': 'TCDS COMPUTER EDUCATION',
#   'PublishedAt': '2023-03-31T16:08:25Z',
#   'Video_Count': 12},
#  {'Playlist_Id': 'PLidfJaBTFqtuuxce6r1sdAJ_BNfIdNpIv',
#   'Title': '2. FRANCHISE WANTED',
#   'Channel_Id': 'UCVRi4KY1YQ6kNkKgR-pvk0A',
#   'Channel_Name': 'TCDS COMPUTER EDUCATION',
#   'PublishedAt': '2021-10-18T15:37:46Z',
#   'Video_Count': 12},
#  {'Playlist_Id': 'PLidfJaBTFqtsSSjj_FgFBjaz3hX7kQqgN',
#   'Title': '1. STAFF WANTED',
#   'Channel_Id': 'UCVRi4KY1YQ6kNkKgR-pvk0A',
#   'Channel_Name': 'TCDS COMPUTER EDUCATION',
#   'PublishedAt': '2021-10-17T08:57:52Z',
#   'Video_Count': 2}]

# %%
#upload to Mongodb
client = pymongo.MongoClient("mongodb+srv://srirampalanivelb:yLvj5AE0h6S40yIT@cluster0.ewmavk0.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0")
db = client["youtube_data"]

# %%
def channel_details(channel_id):
    ch_details = get_channel_info(channel_id)
    pl_details = get_playlist_details(channel_id)
    vi_ids = get_video_ids(channel_id)
    vi_details = get_video_info(vi_ids)
    com_details = get_comment_info(vi_ids)

    coll1 = db["channel_details"]
    coll1.insert_one({"channel_information":ch_details,"playlist_information":pl_details,
                      "video_information":vi_details,"comment_information":com_details})
    
    return "upload completed successfully"

# %%
# channel ID (TCDS)                       - 'UCVRi4KY1YQ6kNkKgR-pvk0A' (+)
# channel ID (mr.gk)                      - 'UC5cY198GU1MQMIPJgMkCJ_Q' (+)
# channel ID (tamil bussiness podcast)    - 'UCy1lBBbXhtfzugF_LK2b6Yw' (+)
# channel ID (science with sam)           - 'UChGd9JY4yMegY6PxqpBjpRA' (+)
# channel ID (Chandru Bharathy)           - 'UCS9ylflS6E0AvXg0LZ0P6_g' (+)
# channel ID (King Kepler Network)        - 'UC3k6Cfk_BNGiGVX_s5UCs6Q'
# channel ID (Tamil trending Media)       - 'UCna0KHJFL0Ru81pwI2tCbGw'
# channel ID (Tamil Academy)              - 'UCbJ9KR5rKDrjzIamrbUmEKQ'
# channel ID (Endless Knowledga)          - 'UCApUMSkgDT8ayJZU8jBweYw'
# channel ID (Error Makes Clever Academy) - 'UCwr-evhuzGZgDFrq_1pLt_A' (+)

# %%
insert = channel_details('UC3k6Cfk_BNGiGVX_s5UCs6Q')
# Out:
# ---------------------------------------------------------------------------
# HttpError                                 Traceback (most recent call last)
# Cell In[312], line 1
# ----> 1 insert = channel_details('UC3k6Cfk_BNGiGVX_s5UCs6Q')
#
# Cell In[310], line 5, in channel_details(channel_id)
#       3 pl_details = get_playlist_details(channel_id)
#       4 vi_ids = get_video_ids(channel_id)
# ----> 5 vi_details = get_video_info(vi_ids)
#       6 com_details = get_comment_info(vi_ids)
#       8 coll1 = db["channel_details"]
#
# Cell In[297], line 13, in get_video_info(video_ids)
#       7 for video_id in video_ids:
#       8     request = youtube.videos().list(
#       9         part = "snippet,ContentDetails,statistics",
#      10         id = video_id
#      11     )
# ---> 13     response = request.execute()
#      15     for item in response ['items']:
#      16         data = dict(Channel_Name = item['snippet']['channelTitle'],
#      17                     Channel_Id = item['snippet']['channelId'],
#      18                     Video_Id = item['id'],
#    (...)
#      30                     Caption_status = item['contentDetails']['caption']
#      31                     )
#
# File c:\Users\manvi\AppData\Local\Programs\Python\Python312\Lib\site-packages\googleapiclient\_helpers.py:130, in positional.<locals>.positional_decorator.<locals>.positional_wrapper(*args, **kwargs)
#     128     elif positional_parameters_enforcement == POSITIONAL_WARNING:
#     129         logger.warning(message)
# --> 130 return wrapped(*args, **kwargs)
#
# File c:\Users\manvi\AppData\Local\Programs\Python\Python312\Lib\site-packages\googleapiclient\http.py:938, in HttpRequest.execute(self, http, num_retries)
#     936     callback(resp)
#     937 if resp.status >= 300:
# --> 938     raise HttpError(resp, content, uri=self.uri)
#     939 return self.postproc(resp, content)
#
# HttpError: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/videos?part=snippet%2CContentDetails%2Cstatistics&id=gI-2ShQgNLU&key=AIzaSyAorTAYXklQGb2YNZClduvQcZynl7O7e5Q&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">

# %%
insert
# Out:
# 'upload completed successfully'

# %%
try:
    mydb = psycopg2.connect(host="localhost",
                                user="postgres",
                                password="12345678",
                                database="youtube_data",
                                port="5432")
    print(mydb)
except psycopg2.DatabaseError as error:
    print(error)
# Out:
# <connection object at 0x0000020518C8CAE0; dsn: 'user=postgres password=xxx dbname=youtube_data host=localhost port=5432', closed: 0>

# %%
mydb = psycopg2.connect(host="localhost",
                            user="postgres",
                            password="12345678",
                            database="youtube_data",
                            port="5432")

cursor = mydb.cursor()
cursor.execute("SELECT version();")
db_version = cursor.fetchone()
print("Database version:", db_version)

try:
    create_query='''create table if not exists channels(Channel_Name varchar(150),
                                                        Channel_Id varchar(100) primary key,
                                                        Subscribers bigint,
                                                        Views bigint,
                                                        Total_Videos int,
                                                        Channel_Description text,
                                                        Playlist_Id varchar(80))'''
    cursor.execute(create_query)
    mydb.commit()

except:
    print("Channels table already created")
# Out:
# Database version: ('PostgreSQL 16.3, compiled by Visual C++ build 1938, 64-bit',)

# %%
    #Table creation for channels,playlists,videos,comments

# def channels_table():
mydb = psycopg2.connect(host="localhost",
                        user="postgres",
                        password="12345678",
                        database="youtube_data",
                        port="5432")

cursor = mydb.cursor() 

drop_query = '''drop table if exists channels'''
cursor.execute(drop_query)
mydb.commit()

# try:
create_query='''create table if not exists channels(Channel_Name varchar(150),
                                                    Channel_Id varchar(100) primary key,
                                                    Subscribers bigint,
                                                    Views bigint,
                                                    Total_Videos int,
                                                    Channel_Description text,
                                                    Playlist_Id varchar(80))'''
cursor.execute(create_query)
mydb.commit()

# except:
#     print("Channels table already created")


# ch_list = []
# db = client["youtube_data"]
# coll1 = db["channel_details"]

# for ch_data in coll1.find({},{"_id":0,"channel_information":1}):
#     ch_list.append(ch_data["channel_information"])

# df = pd.DataFrame(ch_list)   
# print(df.columns) 


# for index,row in df.iterrows():
#     insert_query = '''insert into channels(Channel_Name,
#                                             Channel_Id,
#                                             Subscribers,
#                                             Views,
#                                             Total_Videos,
#                                             Channel_Description,
#                                             Playlist_Id)
                                            
                                            
#                                             values(%s,%s,%s,%s,%s,%s,%s)'''
#     values = (row['Channel_Name'],
#             row['Channel_Id'],
#             row['Subscribers'],
#             row['Views'],
#             row['Total_Videos'],
#             row['Channel_Description'],
#             row['Playlist_Id'])
            
#     try:
#         cursor.execute(insert_query,values)
#         mydb.commit()

#     except:
#         print("Channels values are already inserted")

# %%
def channels_table():
    ch_list = []
    db = client["youtube_data"]
    coll1 = db["channel_details"]

    for ch_data in coll1.find({},{"_id":0,"channel_information":1}):
        ch_list.append(ch_data["channel_information"])

    df = pd.DataFrame(ch_list)   
    print(df.columns)

    return df

# %%
df = channels_table()
# Out:
# Index(['Channel_Name', 'Channel_Id', 'Subscribers', 'Views', 'Total_Videos',
#        'Channel_Description', 'Playlist_Id'],
#       dtype='object')

# %%
for index,row in df.iterrows():
    insert_query = '''insert into channels(Channel_Name,
                                                    Channel_Id,
                                                    Subscribers,
                                                    Views,
                                                    Total_Videos,
                                                    Channel_Description,
                                                    Playlist_Id)
                                                    
                                                    
                                                    values(%s,%s,%s,%s,%s,%s,%s)'''
    values = (row['Channel_Name'],
            row['Channel_Id'],
            row['Subscribers'],
            row['Views'],
            row['Total_Videos'],
            row['Channel_Description'],
            row['Playlist_Id'])
            
    try:
        cursor.execute(insert_query,values)
        mydb.commit()

    except:
        print("Channels values are already inserted")

# %%
# channels_table()

# %%
df.columns
# Out:
# Index(['Channel_Name', 'Channel_Id', 'Subscribers', 'Views', 'Total_Videos',
#        'Channel_Description', 'Playlist_Id'],
#       dtype='object')

# %%
# ch_details = channels_table()

# %%
#create playlisyt table

# def playlist_table():
mydb = psycopg2.connect(host="localhost",
                        user="postgres",
                        password="12345678",
                        database="youtube_data",
                        port="5432")
cursor = mydb.cursor() 

drop_query = '''drop table if exists playlists'''
cursor.execute(drop_query)
mydb.commit()


create_query='''create table if not exists playlists(Playlist_Id varchar(100),
                                                        Title varchar(100),
                                                        Channel_Id varchar(100),
                                                        Channel_Name varchar(100),
                                                        PublishedAt timestamp,
                                                        Video_Count int
                                                        )'''

cursor.execute(create_query)
mydb.commit()


# pl_list = []
# db = client["youtube_data"] 
# coll1 = db["channel_details"]

# for pl_data in coll1.find({},{"_id":0,"playlist_information":1}):
#         for i in range(len(pl_data["playlist_information"])):
#         pl_list.append(pl_data["playlist_information"][i])

# df1 = pd.DataFrame(pl_list)


# for index,row in df1.iterrows():
#         insert_query = '''insert into playlists(Playlist_Id,
#                                                 Title,
#                                                 Channel_Id,
#                                                 Channel_Name,
#                                                 PublishedAt,
#                                                 Video_Count)                                                
                                                
                                                
#                                                 values(%s,%s,%s,%s,%s,%s)'''
#         values = (row['Playlist_Id'],
#         row['Title'],
#         row['Channel_Id'],
#         row['Channel_Name'],
#         row['PublishedAt'],
#         row['Video_Count']
#         )

#         cursor.execute(insert_query,values)
#         mydb.commit()

# %%
def playlist_table():
    pl_list = []
    db = client["youtube_data"] 
    coll1 = db["channel_details"]

    for pl_data in coll1.find({},{"_id":0,"playlist_information":1}):
        for i in range(len(pl_data["playlist_information"])):
            pl_list.append(pl_data["playlist_information"][i])

    df1 = pd.DataFrame(pl_list)

    return df1

# %%
df1 = playlist_table()

# %%
for index,row in df1.iterrows():
    insert_query = '''insert into playlists(Playlist_Id,
                                            Title,
                                            Channel_Id,
                                            Channel_Name,
                                            PublishedAt,
                                            Video_Count)                                                
                                            
                                            
                                            values(%s,%s,%s,%s,%s,%s)'''
    values = (row['Playlist_Id'],
    row['Title'],
    row['Channel_Id'],
    row['Channel_Name'],
    row['PublishedAt'],
    row['Video_Count']
    )

    cursor.execute(insert_query,values)
    mydb.commit()

# %%
#create videos table

# def videos_table():
mydb = psycopg2.connect(host="localhost",
                        user="postgres",
                        password="12345678",
                        database="youtube_data",
                        port="5432")
cursor = mydb.cursor() 

drop_query = '''drop table if exists videos'''
cursor.execute(drop_query)
mydb.commit()


create_query='''create table if not exists videos(channel_name varchar(100),
                                                    channel_Id varchar(100),
                                                    video_id varchar(30),
                                                    Title varchar(150),
                                                    Tags text,
                                                    Thumbnail varchar(200),
                                                    Description text,
                                                    Published_Date timestamp,
                                                    Duration interval,
                                                    Views bigint,
                                                    Likes bigint,
                                                    Comments int,
                                                    Favorite_count int,
                                                    Definition varchar(10),
                                                    Caption_status varchar(50) 
                                                    )'''

cursor.execute(create_query)
mydb.commit()

# vi_list = []
# db = client["youtube_data"] 
# coll1 = db["channel_details"]

# for vi_data in coll1.find({},{"_id":0,"video_information":1}):
#     for i in range(len(vi_data["video_information"])):
#         vi_list.append(vi_data["video_information"][i])

# df2 = pd.DataFrame(vi_list)


# for index,row in df2.iterrows():
#         insert_query = '''insert into videos(channel_name,
#                                                     channel_Id,
#                                                     video_id,
#                                                     Title,
#                                                     Tags,
#                                                     Thumbnail,
#                                                     Description,
#                                                     Published_Date,
#                                                     Duration,
#                                                     Views,
#                                                     Likes,
#                                                     Comments,
#                                                     Favorite_count,
#                                                     Definition,
#                                                     Caption_status)                                               
                                                
                                                
#                                                 values(%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s)'''
#         values = (row['Channel_Name'],
#                 row['Channel_Id'],
#                 row['Video_Id'],
#                 row['Title'],
#                 row['Tags'],
#                 row['Thumbnail'],
#                 row['Description'],
#                 row['Published_Date'],
#                 row['Duration'],
#                 row['Views'],
#                 row['Likes'],
#                 row['Comments'],
#                 row['Favorite_Count'],
#                 row['Definition'],
#                 row['Caption_Status']
#                 )
                
    
# cursor.execute(insert_query,values)
# mydb.commit()

# %%
def videos_table():
    vi_list = []
    db = client["youtube_data"] 
    coll1 = db["channel_details"]

    for vi_data in coll1.find({},{"_id":0,"video_information":1}):
        for i in range(len(vi_data["video_information"])):
            vi_list.append(vi_data["video_information"][i])

    df2 = pd.DataFrame(vi_list)

    return df2

# %%
df2 = videos_table()

# %%
df2.columns
# Out:
# Index(['Channel_Name', 'channel_Id', 'Video_Id', 'Title', 'Tags', 'Thumbnail',
#        'Description', 'Published_Date', 'Duration', 'Views', 'Likes',
#        'Comments', 'Favorite_count', 'Definition', 'Caption_status',
#        'Channel_Id'],
#       dtype='object')

# %%
for index,row in df2.iterrows():
    insert_query = '''insert into videos(Channel_name,
                                        Channel_Id,
                                        Video_id,
                                        Title,
                                        Tags,
                                        Thumbnail,
                                        Description,
                                        Published_Date,
                                        Duration,
                                        Views,
                                        Likes,
                                        Comments,
                                        Favorite_count,
                                        Definition,
                                        Caption_status)                                               
                                                
                                                
                                                values(%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s)'''
    values = (row['Channel_Name'],
                row['channel_Id'],
                row['Video_Id'],
                row['Title'],
                row['Tags'],
                row['Thumbnail'],
                row['Description'],
                row['Published_Date'],
                row['Duration'],
                row['Views'],
                row['Likes'],
                row['Comments'],
                row['Favorite_count'],
                row['Definition'],
                row['Caption_status']
                )
                
    
cursor.execute(insert_query,values)
mydb.commit()

# %%
# create comments Table

# def comments_table():
mydb = psycopg2.connect(host="localhost",
                        user="postgres",
                        password="12345678",
                        database="youtube_data",
                        port="5432")
cursor = mydb.cursor() 

drop_query = '''drop table if exists comments'''
cursor.execute(drop_query)
mydb.commit()


create_query='''create table if not exists comments(Comment_Id varchar(100) primary key,
                                                    Video_Id varchar(50),
                                                    Comment_Text text,
                                                    Comment_Author varchar(150),
                                                    Comment_Published timestamp
                                                    )'''

cursor.execute(create_query)
mydb.commit()

# com_list = []
# db = client["youtube_data"] 
# coll1 = db["channel_details"]

# for com_data in coll1.find({},{"_id":0,"comment_information":1}):
#     for i in range(len(com_data["comment_information"])):
#         com_list.append(com_data["comment_information"][i])

# df3 = pd.DataFrame(com_list)

# for index,row in df3.iterrows():
#         insert_query = '''insert into comments(Comment_Id,
#                                                     Video_Id,
#                                                     Comment_Text,
#                                                     Comment_Author,
#                                                     Comment_Published
#                                                     )                                               

                                                
#                                                 values(%s,%s,%s,%s,%s)'''
                                                
#         values = (row['Comment_Idd'],
#                 row['Video_Id'],
#                 row['Comment_Text'],
#                 row['Comment_Author'],
#                 row['Comment_Publishedt']
#                 )
                
# cursor.execute(insert_query,values)
# mydb.commit()

# %%
def comments_table():
    com_list = []
    db = client["youtube_data"] 
    coll1 = db["channel_details"]

    for com_data in coll1.find({},{"_id":0,"comment_information":1}):
        for i in range(len(com_data["comment_information"])):
            com_list.append(com_data["comment_information"][i])

    df3 = pd.DataFrame(com_list)

    return df3

# %%
df3 = comments_table()

# %%
df3.columns
# Out:
# Index(['Comment_Id', 'Video_Id', 'Comment_Text', 'Comment_Author',
#        'Comment_Published'],
#       dtype='object')

# %%
for index,row in df3.iterrows():
        insert_query = '''insert into comments(Comment_Id,
                                                    Video_Id,
                                                    Comment_Text,
                                                    Comment_Author,
                                                    Comment_Published
                                                    )                                               

                                                
                                                values(%s,%s,%s,%s,%s)'''
                                                
        values = (row['Comment_Id'],
                row['Video_Id'],
                row['Comment_Text'],
                row['Comment_Author'],
                row['Comment_Published']
                )
                
cursor.execute(insert_query,values)
mydb.commit()

# %%
def tables():
    channels_table()
    playlist_table()
    videos_table()
    comments_table()

    return "Table Created Successfully"

# %%
Tables = tables()
# Out:
# Index(['Channel_Name', 'Channel_Id', 'Subscribers', 'Views', 'Total_Videos',
#        'Channel_Description', 'Playlist_Id'],
#       dtype='object')

# %%
Tables
# Out:
# 'Table Created Successfully'

# %%
def show_channels_table():
    ch_list = []
    db = client["youtube_data"]
    coll = db["channel_details"]

    for ch_data in coll.find({},{"_id":0,"channel_information":1}):
        ch_list.append(ch_data["channel_information"])

    df = st.DataFrame(ch_list) 

    return df

# %%
def show_playlists_table():
    pl_list = []
    db = client["youtube_data"] 
    coll = db["channel_details"]

    for pl_data in coll.find({},{"_id":0,"playlist_information":1}):
        for i in range(len(pl_data["playlist_information"])):
            pl_list.append(pl_data["playlist_information"][i])

    df1 = st.DataFrame(pl_list)

    return df1

# %%
def show_video_table():
    vi_list = []
    db = client["youtube_data"] 
    coll = db["channel_details"]

    for vi_data in coll.find({},{"_id":0,"video_information":1}):
        for i in range(len(vi_data["video_information"])):
            vi_list.append(vi_data["video_information"][i])

    df2 = st.DataFrame(vi_list)

    return df2

# %%
def show_comments_table():
    com_list = []
    db = client["youtube_data"] 
    coll = db["channel_details"]

    for com_data in coll.find({},{"_id":0,"comment_information":1}):
        for i in range(len(com_data["comment_information"])):
            com_list.append(com_data["comment_information"][i])

    df3 = st.DataFrame(com_list)

    return df3

# %%
df
# Out:
#                             Channel_Name                Channel_Id  \
# 0                TCDS COMPUTER EDUCATION  UCVRi4KY1YQ6kNkKgR-pvk0A
# 1                                 Mr. GK  UC5cY198GU1MQMIPJgMkCJ_Q
# 2             Error Makes Clever Academy  UCwr-evhuzGZgDFrq_1pLt_A
# 3                 Tamil Business Podcast  UCy1lBBbXhtfzugF_LK2b6Yw
# 4  Science With Sam - அறிவியல் அறிவோம் !  UChGd9JY4yMegY6PxqpBjpRA
# 5                       Chandru Bharathy  UCS9ylflS6E0AvXg0LZ0P6_g
#
#   Subscribers      Views Total_Videos  \
# 0        1720      55566          167
# 1     1420000  207688550          524
# 2      638000   38224158          170
# 3       23500     837843           33
# 4       60000    3978521          261
# 5      189000   13344871          233
#
#                                  Channel_Description               Playlist_Id
# 0  இந்த சேனலின் முக்கிய நோக்கம் :\n\n1. அனைவருக்க...  UUVRi4KY1YQ6kNkKgR-pvk0A
# 1  Please contact me at mrgktamil@gmail.com\n\nFo...  UU5cY198GU1MQMIPJgMkCJ_Q
# 2  Empowering developers to level up their skills...  UUwr-evhuzGZgDFrq_1pLt_A
# 3  Welcome to the Tamil Business Podcast, your ul...  UUy1lBBbXhtfzugF_LK2b6Yw
# 4  நான், இயற்பியல் துறையில் முனைவர் பட்டம், ஜப்பா...  UUhGd9JY4yMegY6PxqpBjpRA
# 5  Hello Wedding photography enthusiasts!\n\nAre ...  UUS9ylflS6E0AvXg0LZ0P6_g

# %%
# streamlit part 

with st.sidebar:
    st.title(":blue[YOUTUBE DATA HARVESTING & WEREHOUSING]")
    st.header("SKILL TAKE AWAY")
    st.caption("PYTHON SCRIPTING")
    st.caption("DATA COLLECTION")
    st.caption("MongoDB")
    st.caption("API Integration")
    st.caption("Data Management using MongoDB and SQL")

channel_id = st.text_input("Enter the channel ID")

if st.button("collect and store data"):
    ch_ids = []
    db = client["youtube_sata"]
    coll1 = db["channel_details"]
    for ch_data in coll1.find({},{"_id":0,"channel_information":1}):
        ch_ids.append(ch_data["channel_information"]["Channel_Id"])

    if channel_id in ch_ids:
        st.success("Channel Details of given channel id already exists")

    else:
        insert = channel_details(channel_id)
        st.success(insert)

if st.button("Migrate to Sql"):
    Table = tables()
    st.success(Table)

show_table = st.radio("SELECT THE TABLE FOR VIEW",("CHANNELS","PLATLISTS","VIDEOS","COMMENTS"))

if show_table == "CHANNELS":
    show_channels_table()

elif show_table == "PLAYLISTS":
    show_playlists_table()

elif show_table == "VIDEOS":
    show_video_table()

elif show_table == "COMMENTS":
    show_comments_table()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[282], line 35
#      32 show_table = st.radio("SELECT THE TABLE FOR VIEW",("CHANNELS","PLATLISTS","VIDEOS","COMMENTS"))
#      34 if show_table == "CHANNELS":
# ---> 35     show_channels_table()
#      37 elif show_table == "PLAYLISTS":
#      38     show_playlists_table()
#
# Cell In[277], line 9, in show_channels_table()
#       6 for ch_data in coll.find({},{"_id":0,"channel_information":1}):
#       7     ch_list.append(ch_data["channel_information"])
# ----> 9 df = st.DataFrame(ch_list)
#      11 return df
#
# AttributeError: module 'streamlit' has no attribute 'DataFrame'

# %%
# Queries

mydb = psycopg2.connect(host="localhost",
                            user="postgres",
                            password="12345678",
                            database="youtube_data",
                            port="5432")
cursor = mydb.cursor()


question = st.selectbox("Select your question",("1. All the videos and the channel name",
                                                "2. channels with most number of videos",
                                                "3. 10 most viewed videos",
                                                "4. comments in each videos",
                                                "5. Videos with highest likes",
                                                "6. likes of all videos",
                                                "7. views of each channel",
                                                "8. videos published in the year of 2022",
                                                "9. average duration of all videos in each channel",
                                                "10. videos with highest number of comments"))


if question == "1. All the videos and the channel name":
    query1 = '''select title as videos,channel_name as channelname from videos'''
    cursor.execute(query1)
    mydb.commit()
    t1 = cursor.fetchall()
    df = pd.DataFrame(t1,columns=["title of video","name of the channel"])
    st.write(df)

elif question == "2. channels with most number of videos":
    query2 = '''select channel_name as channelname,total_videos as no_videos from channels
                order by total_videos desc'''
    cursor.execute(query2)
    mydb.commit()
    t2 = cursor.fetchall()
    df2 = pd.DataFrame(t2,columns=["channel name","no of videos"])
    st.write(df2)

elif question ==  "3. 10 most viewed videos":
    query3 = '''select views as view,channel_name as channelname,title as videotitle from videos
                where views is not null order by views desc limit 10'''
    cursor.execute(query3)
    mydb.commit()
    t3 = cursor.fetchall()
    df3 = pd.DataFrame(t3,columns=["views","channelname","videotitle"])
    st.write(df3)

elif question ==   "4. comments in each videos":
    query4 = '''select comments as no_comments,title as videotitle from videos where comments is not null '''
    cursor.execute(query4)
    mydb.commit()
    t4 = cursor.fetchall()
    df4 = pd.DataFrame(t4,columns=["no of comments","videotitle"])
    st.write(df4)


elif question ==   "5. Videos with highest likes":
    query5 = '''select title as videotitle,channel_name as channelname, likes as likecount
                from videos where likes is not null order by likes desc'''
    cursor.execute(query5)
    mydb.commit()
    t5 = cursor.fetchall()
    df5 = pd.DataFrame(t5,columns=["videotitle","channelname","likecount"])
    st.write(df5)

elif question ==   "6. likes of all videos":
    query6 = '''select likes as likecount,title as videotitle from videos'''
    cursor.execute(query6)
    mydb.commit()
    t6 = cursor.fetchall()
    df6 = pd.DataFrame(t6,columns=["likecount","videotitle"])
    st.write(df6)

elif question ==   "7. views of each channel":
    query7 = '''select channel_name as channelname, views as totalviews from channels'''
    cursor.execute(query7)
    mydb.commit()
    t7 = cursor.fetchall()
    df7 = pd.DataFrame(t7,columns=["channel name","totalviews"])
    st.write(df7)


elif question ==   "8. videos published in the year of 2022":
    query8 = '''select title as video_title, published_date as videorelease,channel_name as channelname from videos
                where extract(year from published_date)=2022'''
    cursor.execute(query8)
    mydb.commit()
    t8 = cursor.fetchall()
    df8 = pd.DataFrame(t8,columns=["videotitle","published_date","channelname"])
    st.write(df8)


elif question ==   "9. average duration of all videos in each channel":
    query9 = '''select channel_name as channelname, AVG(duration) as averageduration from videos
                group by channel_name'''
    cursor.execute(query9)
    mydb.commit()
    t9 = cursor.fetchall()
    df9 = pd.DataFrame(t9,columns=["channelname","averageduration"])
    st.write(df9)

    T9 = []
    for index,row in df9.iterrows():
        channel_title = row["channelname"]
        average_duration = row["averageduration"]
        average_duration_str = str(average_duration)
        T9.append(dict(channeltitle = channel_title, avgduration = average_duration_str))
    df1 = pd.DataFrame(T9)


elif question ==   "10. videos with highest number of comments":
    query10 = '''select title as videotitle, channel_name as channelname, comments as commentts from videos where comments
                is not null order by comments desc'''
    cursor.execute(query10)
    mydb.commit()
    t10 = cursor.fetchall()
    df10 = pd.DataFrame(t10,columns=["video title","channel name","comments"])
    st.write(df10)

# %%
# Answer taking for query

mydb = psycopg2.connect(host="localhost",
                            user="postgres",
                            password="12345678",
                            database="youtube_data",
                            port="5432")
cursor = mydb.cursor()

if question ==   "10. videos with highest number of comments":
    query10 = '''select title as videotitle, channel_name as channelname, comments as commentts from videos where comments
                is not null order by comments desc'''
    cursor.execute(query10)
    mydb.commit()
    t10 = cursor.fetchall()
    df10 = pd.DataFrame(t10,columns=["video title","channel name","comments"])
    st.write(df10)
